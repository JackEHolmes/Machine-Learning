# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns
import warnings
import platform
import datetime
import lightgbm as lgb
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import confusion_matrix
from sklearn.externals import joblib
#from fastFM import als
import scipy
import sys
import time
import xlearn as xl
# %matplotlib inline
warnings.filterwarnings("ignore")
# Out:
# /Users/she/anaconda3/lib/python3.6/site-packages/lightgbm/__init__.py:46: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_9.4.1) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)

# %%
mod = [np, pd, matplotlib, sklearn, sns]
mod_str = ['numpy', 'pandas', 'matplotlib', 'sklearn', 'seaborn']
max_len = max(len(i)for i in mod_str)
print("{{:<{}}} version: {{}}".format(max_len).format('Platform', platform.platform()))
print("{{:<{}}} version: {{}}".format(max_len).format('Python',sys.version))
for m, ms in zip(mod, mod_str):
    print("{{:<{}}} version: {{.__version__}}".format(max_len).format(ms,m))
# Out:
# Platform   version: Darwin-18.2.0-x86_64-i386-64bit
# Python     version: 3.6.6 | packaged by conda-forge | (default, Jul 26 2018, 09:55:02)
# [GCC 4.2.1 Compatible Apple LLVM 6.1.0 (clang-602.0.53)]
# numpy      version: 1.14.6
# pandas     version: 0.23.4
# matplotlib version: 3.0.1
# sklearn    version: 0.20.0
# seaborn    version: 0.9.0

# %% [markdown]
# # Data Exploration

# %%
pd.read_excel('Data_Dictionary.xlsx', sheet_name='train')
# Out:
#             train.csv                                         Unnamed: 1
# 0                 NaN                                                NaN
# 1             Columns                                        Description
# 2             card_id                             Unique card identifier
# 3  first_active_month                 'YYYY-MM', month of first purchase
# 4           feature_1                Anonymized card categorical feature
# 5           feature_2                Anonymized card categorical feature
# 6           feature_3                Anonymized card categorical feature
# 7              target  Loyalty numerical score calculated 2 months af...

# %%
train = pd.read_csv("train.csv", parse_dates=['first_active_month'])

# %%
print(train.corr())
sns.heatmap(train.corr())
# Out:
#            feature_1  feature_2  feature_3    target
# feature_1   1.000000  -0.130969   0.583092 -0.014251
# feature_2  -0.130969   1.000000   0.060925 -0.006242
# feature_3   0.583092   0.060925   1.000000 -0.008125
# target     -0.014251  -0.006242  -0.008125  1.000000

# %%
train.info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201917 entries, 0 to 201916
# Data columns (total 6 columns):
# first_active_month    201917 non-null datetime64[ns]
# card_id               201917 non-null object
# feature_1             201917 non-null int64
# feature_2             201917 non-null int64
# feature_3             201917 non-null int64
# target                201917 non-null float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(1)
# memory usage: 9.2+ MB

# %%
pd.read_csv("historical_transactions.csv").info(memory_usage=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29112361 entries, 0 to 29112360
# Data columns (total 14 columns):
# authorized_flag         object
# card_id                 object
# city_id                 int64
# category_1              object
# installments            int64
# category_3              object
# merchant_category_id    int64
# merchant_id             object
# month_lag               int64
# purchase_amount         float64
# purchase_date           object
# category_2              float64
# state_id                int64
# subsector_id            int64
# dtypes: float64(2), int64(6), object(6)
# memory usage: 3.0+ GB

# %%
pd.read_excel('Data_Dictionary.xlsx', sheet_name='history')
# Out:
#    historical_transactions.csv  \
# 0                          NaN
# 1                      Columns
# 2                      card_id
# 3                    month_lag
# 4                purchase_date
# 5              authorized_flag
# 6                   category_3
# 7                 installments
# 8                   category_1
# 9         merchant_category_id
# 10                subsector_id
# 11                 merchant_id
# 12             purchase_amount
# 13                     city_id
# 14                    state_id
# 15                  category_2
#
#                                           Unnamed: 1
# 0                                                NaN
# 1                                        Description
# 2                                    Card identifier
# 3                        month lag to reference date
# 4                                      Purchase date
# 5                      Y' if approved, 'N' if denied
# 6                                anonymized category
# 7                 number of installments of purchase
# 8                                anonymized category
# 9         Merchant category identifier (anonymized )
# 10  Merchant category group identifier (anonymized )
# 11                  Merchant identifier (anonymized)
# 12                        Normalized purchase amount
# 13                     City identifier (anonymized )
# 14                    State identifier (anonymized )
# 15                               anonymized category

# %% [markdown]
# ## train----target

# %%
print(train.target.describe())
plt.figure(figsize=(20,12))
sns.distplot(train.target, bins=np.arange(-34, 19, 1), vertical=True)
# Out:
# count    201917.000000
# mean         -0.393636
# std           3.850500
# min         -33.219281
# 25%          -0.883110
# 50%          -0.023437
# 75%           0.765453
# max          17.965068
# Name: target, dtype: float64

# %%
print(train.target[train.target>-30].describe())
# Out:
# count    199710.000000
# mean         -0.030879
# std           1.717793
# min         -17.608147
# 25%          -0.844513
# 50%          -0.007783
# 75%           0.777331
# max          17.965068
# Name: target, dtype: float64

# %%
train.target[train.target<-20].value_counts()
# Out:
# -33.219281    2207
# Name: target, dtype: int64

# %%
2207/199710
# Out:
# 0.011051023984777928

# %%
plt.figure(figsize=(20,12))
sns.distplot(train.target[train.target>-30], bins=np.arange(-18, 18, 0.1))

# %% [markdown]
# ## Features 1, 2, 3

# %%
fig, ax = plt.subplots(1, 3, figsize = (16, 6))
plt.suptitle('Violineplots for features and target');
sns.violinplot(x="feature_1", y="target", data=train, ax=ax[0], title='feature_1');
sns.violinplot(x="feature_2", y="target", data=train, ax=ax[1], title='feature_2');
sns.violinplot(x="feature_3", y="target", data=train, ax=ax[2], title='feature_3');

# %%
fig, ax = plt.subplots(1, 3, figsize = (16, 6));
train['feature_1'].value_counts().sort_index().plot(kind='bar', ax=ax[0], color='teal', title='feature_1');
train['feature_2'].value_counts().sort_index().plot(kind='bar', ax=ax[1], color='brown', title='feature_2');
train['feature_3'].value_counts().sort_index().plot(kind='bar', ax=ax[2], color='gold', title='feature_3');
plt.suptitle('Counts of categiories for features');

# %% [markdown]
# ## train----first_active_month

# %%
sns.barplot(train.groupby(["first_active_month"]).count().index, \
            train.groupby(["first_active_month"]).count().card_id)

# %%
sns.barplot(train[train['target']<-30].groupby(["first_active_month"]).count().index, \
            train[train['target']<-30].groupby(["first_active_month"]).count().card_id)
plt.title("First active month count in target low than -30")
# Out:
# Text(0.5, 1.0, 'First active month count in target low than -30')

# %% [markdown]
# ## historical_transactions--card_id

# %%
ht = pd.read_csv("historical_transactions.csv", error_bad_lines=False)

# %%
ht.columns
# Out:
# Index(['authorized_flag', 'card_id', 'city_id', 'category_1', 'installments',
#        'category_3', 'merchant_category_id', 'merchant_id', 'month_lag',
#        'purchase_amount', 'purchase_date', 'category_2', 'state_id',
#        'subsector_id'],
#       dtype='object')

# %%
ht.head()
# Out:
#   authorized_flag          card_id  city_id category_1  installments  \
# 0               Y  C_ID_4e6213e9bc       88          N             0
# 1               Y  C_ID_4e6213e9bc       88          N             0
# 2               Y  C_ID_4e6213e9bc       88          N             0
# 3               Y  C_ID_4e6213e9bc       88          N             0
# 4               Y  C_ID_4e6213e9bc       88          N             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                    80  M_ID_e020e9b302         -8
# 1          A                   367  M_ID_86ec983688         -7
# 2          A                    80  M_ID_979ed661fc         -6
# 3          A                   560  M_ID_e6d5ae8ea6         -5
# 4          A                    80  M_ID_e020e9b302        -11
#
#    purchase_amount        purchase_date  category_2  state_id  subsector_id
# 0        -0.703331  2017-06-25 15:33:07         1.0        16            37
# 1        -0.733128  2017-07-15 12:10:45         1.0        16            16
# 2        -0.720386  2017-08-09 22:04:29         1.0        16            37
# 3        -0.735352  2017-09-02 10:06:26         1.0        16            34
# 4        -0.722865  2017-03-10 01:14:19         1.0        16            37

# %%
series_ht_cardid_count = ht.card_id.value_counts()

# %%
series_ht_cardid_count.values
# Out:
# array([5582, 2912, 2143, ...,    2,    2,    2])

# %%
ht_cardid_count = pd.DataFrame([series_ht_cardid_count.index, series_ht_cardid_count.values]).T

# %%
ht_cardid_count.rename(columns={0: "card_id", 1: "ht_cardid_counts"}, inplace=True)
ht_cardid_count.head()
# Out:
#            card_id ht_cardid_counts
# 0  C_ID_3d3dfdc692             5582
# 1  C_ID_0cd2ce025c             2912
# 2  C_ID_cc3d4cd4e3             2143
# 3  C_ID_5ccc07beb9             2066
# 4  C_ID_5ea401d358             1786

# %%
train_ht_merge = pd.merge(train[["card_id", "target"]], ht_cardid_count, 'left', 'card_id')
train_ht_merge.head()
# Out:
#            card_id    target ht_cardid_counts
# 0  C_ID_92a2005557 -0.820283              260
# 1  C_ID_3d0044924f  0.392913              350
# 2  C_ID_d639edf6cd  0.688056               43
# 3  C_ID_186d6a6901  0.142495               77
# 4  C_ID_cdbd2c0db2 -0.159749              133

# %%
sns.scatterplot(train_ht_merge["ht_cardid_counts"], train_ht_merge["target"])

# %% [markdown]
# ## Missing value

# %%
train.isnull().sum()
# Out:
# first_active_month    0
# card_id               0
# feature_1             0
# feature_2             0
# feature_3             0
# target                0
# dtype: int64

# %%
ht.isnull().sum()
total = ht.isnull().sum().sort_values(ascending = False)
percent = (ht.isnull().sum()/ht.isnull().count()*100).sort_values(ascending = False)
missing_data  = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                         Total   Percent
# category_2            2652864  9.112500
# category_3             178159  0.611970
# merchant_id            138481  0.475678
# subsector_id                0  0.000000
# state_id                    0  0.000000
# purchase_date               0  0.000000
# purchase_amount             0  0.000000
# month_lag                   0  0.000000
# merchant_category_id        0  0.000000
# installments                0  0.000000
# category_1                  0  0.000000
# city_id                     0  0.000000
# card_id                     0  0.000000
# authorized_flag             0  0.000000

# %% [markdown]
# ## historical_transactions----month_lag

# %%
print(ht.month_lag.value_counts())
sns.barplot(x=ht.month_lag.value_counts().index, y=ht.month_lag.value_counts().values,)
# Out:
# -2     3857276
# -1     3627430
#  0     3470946
# -3     3095651
# -4     2639805
# -5     2364790
# -6     2050048
# -7     1769844
# -8     1427846
# -9     1234724
# -10    1085053
# -11    1007878
# -12     791973
# -13     689097
# Name: month_lag, dtype: int64

# %% [markdown]
# ## historical_transactions----purchase_date

# %%
ht["purchase_date"].head()
# Out:
# 0    2017-06-25 15:33:07
# 1    2017-07-15 12:10:45
# 2    2017-08-09 22:04:29
# 3    2017-09-02 10:06:26
# 4    2017-03-10 01:14:19
# Name: purchase_date, dtype: object

# %% [markdown]
# ## historical_transactions----authorized_flag

# %%
print(ht.authorized_flag.value_counts())
ht.authorized_flag.value_counts().plot(kind="pie")
# Out:
# Y    26595452
# N     2516909
# Name: authorized_flag, dtype: int64

# %% [markdown]
# ## historical_transactions----category_3

# %%
print(ht.category_3.value_counts())
ht.category_3.value_counts().plot(kind="pie")
# Out:
# A    15411747
# B    11677522
# C     1844933
# Name: category_3, dtype: int64

# %% [markdown]
# ## historical_transactions----category_1

# %%
print(ht.category_1.value_counts())
ht.category_1.value_counts().plot(kind="pie")
# Out:
# N    27028332
# Y     2084029
# Name: category_1, dtype: int64

# %% [markdown]
# ## historical_transactions----category_2

# %%
print(ht.category_2.value_counts())
ht.category_2.value_counts().plot(kind="pie")
# Out:
# 1.0    15177199
# 3.0     3911795
# 5.0     3725915
# 4.0     2618053
# 2.0     1026535
# Name: category_2, dtype: int64

# %%
print(ht.installments.value_counts())
# Out:
#  0      15411747
#  1      11677522
#  2        666416
#  3        538207
#  4        179525
# -1        178159
#  6        132634
#  10       118827
#  5        116090
#  12        55064
#  8         20474
#  7         10906
#  9          5772
#  11          830
#  999         188
# Name: installments, dtype: int64

# %% [markdown]
# ## historical_transactions----installments

# %%
inst_target = pd.merge(train[["card_id", "target"]], ht[["card_id", "installments"]], "left", "card_id").groupby("installments").mean()
inst_target.T
# Out:
# installments      -1         0         1         2         3         4    \
# target       -0.198545 -0.326016 -0.587727 -0.584338 -0.576481 -0.538817
#
# installments       5         6        7         8         9         10   \
# target       -0.562405 -0.547366 -0.71256 -0.563364 -0.591758 -0.567902
#
# installments       11        12        999
# target       -0.742808 -0.784036 -0.835092

# %%
sns.barplot(inst_target.index, inst_target.values.reshape((15,)))

# %% [markdown]
# ## historical_transactions----merchant_category_id

# %%
ht.merchant_category_id.value_counts()
# Out:
# 705    5554009
# 307    3057930
# 278    2254227
# 80     1929413
# 367    1608239
# 879    1430607
# 560    1110681
# 683     822021
# 437     665634
# 690     459101
# 839     445622
# 884     416465
# 108     317938
# 842     315091
# 511     302620
# 68      300512
# 506     292335
# 755     290310
# 222     290186
# 561     272565
# 454     259206
# 422     249513
# 195     227402
# 45      225705
# 360     225270
# 309     222541
# 661     210774
# 557     190599
# 87      179321
# 818     178481
#         ...
# 714         30
# 587         27
# 27          25
# 530         25
# 464         14
# 718         12
# 67          12
# 145         11
# 579          9
# 153          9
# 59           7
# 817          6
# 523          6
# 226          6
# 741          6
# 268          5
# 18           4
# 805          3
# 601          3
# 37           3
# 634          3
# 266          2
# 603          2
# 164          2
# 875          1
# 311          1
# 322          1
# 882          1
# 86           1
# 687          1
# Name: merchant_category_id, Length: 327, dtype: int64

# %% [markdown]
# ## historical_transactions----city_id

# %%
ht.city_id.value_counts()
# Out:
#  69     4835441
# -1      2478624
#  19     1151077
#  158    1113013
#  17      971714
#  331     714414
#  143     668769
#  88      659328
#  137     603023
#  333     561144
#  87      444940
#  212     406196
#  57      382232
#  149     359540
#  25      356757
#  233     355108
#  117     322414
#  160     317617
#  213     248371
#  277     247294
#  286     231877
#  76      216048
#  4       212403
#  107     210182
#  53      209668
#  20      207650
#  291     199983
#  140     190359
#  344     177694
#  161     168745
#          ...
#  32        8382
#  81        8278
#  54        8201
#  235       7918
#  326       7912
#  293       7804
#  327       7499
#  112       7461
#  84        7367
#  237       7285
#  227       7233
#  254       7143
#  71        6781
#  204       6745
#  306       6128
#  221       6096
#  130       5657
#  122       5458
#  205       5385
#  215       4791
#  89        4760
#  178       4430
#  263       4003
#  207       3905
#  315       3845
#  319       1645
#  92         758
#  273        620
#  316        149
#  185         45
# Name: city_id, Length: 308, dtype: int64

# %% [markdown]
# ## historical_transactions----state_id

# %%
ht.state_id.value_counts()
# Out:
#  9     10568881
# -1      2652864
#  16     2143420
#  15     2079255
#  5      1655124
#  19     1204287
#  20     1141197
#  22      971714
#  21      929594
#  4       840820
#  7       640712
#  13      634006
#  11      631127
#  3       542220
#  12      385643
#  18      384876
#  2       371728
#  1       247753
#  10      222463
#  23      206011
#  24      205952
#  14      171513
#  8       157829
#  17      116139
#  6         7233
# Name: state_id, dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
train = pd.read_csv('train.csv', parse_dates=['first_active_month'])
test = pd.read_csv('test.csv', parse_dates=['first_active_month'])
historical_transactions = pd.read_csv('historical_transactions.csv',parse_dates=['purchase_date'])
new_transactions = pd.read_csv('new_merchant_transactions.csv',parse_dates=['purchase_date'])

# %%
def binarize(df):
    for col in ['authorized_flag', 'category_1']:
        df[col] = df[col].map({'Y':1, 'N':0})
    return df
historical_transactions = binarize(historical_transactions)
new_transactions = binarize(new_transactions)

# %%
train['elapsed_time'] = (datetime.date(2018, 2, 1) - train['first_active_month'].dt.date).dt.days
train['elapsed_time'].head()
# Out:
# 0    245
# 1    396
# 2    549
# 3    153
# 4     92
# Name: elapsed_time, dtype: int64

# %%
test['elapsed_time'] = (datetime.date(2018, 2, 1) - test['first_active_month'].dt.date).dt.days
test['elapsed_time'].head()
# Out:
# 0    306.0
# 1    396.0
# 2    184.0
# 3     62.0
# 4    793.0
# Name: elapsed_time, dtype: float64

# %%
Y_train = train['target']
del train['target']

# %%
train.head()
# Out:
#   first_active_month          card_id  feature_1  feature_2  feature_3  \
# 0         2017-06-01  C_ID_92a2005557          5          2          1
# 1         2017-01-01  C_ID_3d0044924f          4          1          0
# 2         2016-08-01  C_ID_d639edf6cd          2          2          0
# 3         2017-09-01  C_ID_186d6a6901          4          3          0
# 4         2017-11-01  C_ID_cdbd2c0db2          1          3          0
#
#    elapsed_time
# 0           245
# 1           396
# 2           549
# 3           153
# 4            92

# %%
historical_transactions['month_diff'] = ((datetime.datetime.today() \
                                          - historical_transactions['purchase_date']).dt.days)//30
historical_transactions['month_diff'] += historical_transactions['month_lag']

# %%
new_transactions['month_diff'] = ((datetime.datetime.today() \
                                   - new_transactions['purchase_date']).dt.days)//30
new_transactions['month_diff'] += new_transactions['month_lag']

# %%
historical_transactions.head()
# Out:
#    authorized_flag          card_id  city_id  category_1  installments  \
# 0                1  C_ID_4e6213e9bc       88           0             0
# 1                1  C_ID_4e6213e9bc       88           0             0
# 2                1  C_ID_4e6213e9bc       88           0             0
# 3                1  C_ID_4e6213e9bc       88           0             0
# 4                1  C_ID_4e6213e9bc       88           0             0
#
#   category_3  merchant_category_id      merchant_id  month_lag  \
# 0          A                    80  M_ID_e020e9b302         -8
# 1          A                   367  M_ID_86ec983688         -7
# 2          A                    80  M_ID_979ed661fc         -6
# 3          A                   560  M_ID_e6d5ae8ea6         -5
# 4          A                    80  M_ID_e020e9b302        -11
#
#    purchase_amount       purchase_date  category_2  state_id  subsector_id  \
# 0        -0.703331 2017-06-25 15:33:07         1.0        16            37
# 1        -0.733128 2017-07-15 12:10:45         1.0        16            16
# 2        -0.720386 2017-08-09 22:04:29         1.0        16            37
# 3        -0.735352 2017-09-02 10:06:26         1.0        16            34
# 4        -0.722865 2017-03-10 01:14:19         1.0        16            37
#
#    month_diff
# 0          10
# 1          10
# 2          11
# 3          11
# 4          11

# %%
historical_transactions = pd.get_dummies(historical_transactions, columns=['category_2', 'category_3'])
new_transactions = pd.get_dummies(new_transactions, columns=['category_2', 'category_3'])

# %%
def reduce_mem_usage(df, verbose=True):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    start_mem = df.memory_usage().sum() / 1024**2    
    for col in df.columns:
        col_type = df[col].dtypes
        if col_type in numerics:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)    
    end_mem = df.memory_usage().sum() / 1024**2
    if verbose: print('Mem. usage decreased to {:5.2f} Mb ({:.1f}% reduction)'.format(end_mem, 100 * (start_mem - end_mem) / start_mem))
    return df

# %%
historical_transactions = reduce_mem_usage(historical_transactions)
new_transactions = reduce_mem_usage(new_transactions)
# Out:
# Mem. usage decreased to 1332.66 Mb (57.1% reduction)
# Mem. usage decreased to 86.12 Mb (58.9% reduction)

# %%
agg_fun = {'authorized_flag': ['mean']}
auth_mean = historical_transactions.groupby(['card_id']).agg(agg_fun)
auth_mean.columns = ['_'.join(col).strip() for col in auth_mean.columns.values]
auth_mean.reset_index(inplace=True)

# %%
authorized_transactions = historical_transactions[historical_transactions['authorized_flag'] == 1]
historical_transactions = historical_transactions[historical_transactions['authorized_flag'] == 0]

# %%
authorized_transactions.shape
# Out:
# (26595452, 21)

# %%
historical_transactions.shape
# Out:
# (2516909, 21)

# %%
historical_transactions['purchase_month'] = historical_transactions['purchase_date'].dt.month
authorized_transactions['purchase_month'] = authorized_transactions['purchase_date'].dt.month
new_transactions['purchase_month'] = new_transactions['purchase_date'].dt.month

# %%
def aggregate_transactions(history):
    
    history.loc[:, 'purchase_date'] = pd.DatetimeIndex(history['purchase_date']).\
                                      astype(np.int64) * 1e-9
    
    agg_func = {
    'category_1': ['sum', 'mean'],
    'category_2_1.0': ['mean'],
    'category_2_2.0': ['mean'],
    'category_2_3.0': ['mean'],
    'category_2_4.0': ['mean'],
    'category_2_5.0': ['mean'],
    'category_3_A': ['mean'],
    'category_3_B': ['mean'],
    'category_3_C': ['mean'],
    'merchant_id': ['nunique'],
    'merchant_category_id': ['nunique'],
    'state_id': ['nunique'],
    'city_id': ['nunique'],
    'subsector_id': ['nunique'],
    'purchase_amount': ['sum', 'mean', 'max', 'min', 'std'],
    'installments': ['sum', 'mean', 'max', 'min', 'std'],
    'purchase_month': ['mean', 'max', 'min', 'std'],
    'purchase_date': [np.ptp, 'min', 'max'],
    'month_lag': ['mean', 'max', 'min', 'std'],
    'month_diff': ['mean']
    }
    
    agg_history = history.groupby(['card_id']).agg(agg_func)
    agg_history.columns = ['_'.join(col).strip() for col in agg_history.columns.values]
    agg_history.reset_index(inplace=True)
    
    df = (history.groupby('card_id')
          .size()
          .reset_index(name='transactions_count'))
    
    agg_history = pd.merge(df, agg_history, on='card_id', how='left')
    
    return agg_history

# %%
history = aggregate_transactions(historical_transactions)
history.columns = ['hist_' + c if c != 'card_id' else c for c in history.columns]
history.head()
# Out:
#            card_id  hist_transactions_count  hist_category_1_sum  \
# 0  C_ID_00007093c1                       35                  4.0
# 1  C_ID_0001238066                        3                  0.0
# 2  C_ID_0001506ef0                        4                  0.0
# 3  C_ID_0001793786                       27                  2.0
# 4  C_ID_000183fdda                        7                  0.0
#
#    hist_category_1_mean  hist_category_2_1.0_mean  hist_category_2_2.0_mean  \
# 0              0.114286                  0.000000                  0.000000
# 1              0.000000                  0.333333                  0.000000
# 2              0.000000                  0.000000                  0.000000
# 3              0.074074                  0.111111                  0.296296
# 4              0.000000                  0.000000                  0.000000
#
#    hist_category_2_3.0_mean  hist_category_2_4.0_mean  \
# 0                  0.885714                       0.0
# 1                  0.000000                       0.0
# 2                  1.000000                       0.0
# 3                  0.111111                       0.0
# 4                  1.000000                       0.0
#
#    hist_category_2_5.0_mean  hist_category_3_A_mean          ...           \
# 0                  0.000000                0.000000          ...
# 1                  0.666667                0.000000          ...
# 2                  0.000000                0.750000          ...
# 3                  0.000000                0.814815          ...
# 4                  0.000000                0.000000          ...
#
#    hist_purchase_month_min  hist_purchase_month_std  hist_purchase_date_ptp  \
# 0                        1                 3.071419              28858113.0
# 1                        2                 5.773503               3609150.0
# 2                        2                 4.725816              22098875.0
# 3                        3                 2.375684              16780236.0
# 4                        8                 0.755929               6701589.0
#
#    hist_purchase_date_min  hist_purchase_date_max  hist_month_lag_mean  \
# 0            1.489250e+09            1.518108e+09            -6.028571
# 1            1.514660e+09            1.518269e+09            -1.333333
# 2            1.496772e+09            1.518871e+09            -2.500000
# 3            1.488636e+09            1.505416e+09            -3.518519
# 4            1.502099e+09            1.508801e+09            -5.714286
#
#    hist_month_lag_max  hist_month_lag_min  hist_month_lag_std  \
# 0                   0                 -11            3.535415
# 1                   0                  -2            1.154701
# 2                   0                  -8            3.785939
# 3                  -1                  -7            2.375684
# 4                  -4                  -6            0.755929
#
#    hist_month_diff_mean
# 0             10.514286
# 1             10.000000
# 2             10.500000
# 3             14.444444
# 4             10.285714
#
# [5 rows x 39 columns]

# %%
authorized = aggregate_transactions(authorized_transactions)
authorized.columns = ['auth_' + c if c != 'card_id' else c for c in authorized.columns]

# %%
authorized.head()
# Out:
#            card_id  auth_transactions_count  auth_category_1_sum  \
# 0  C_ID_00007093c1                      114                 24.0
# 1  C_ID_0001238066                      120                  2.0
# 2  C_ID_0001506ef0                       62                  0.0
# 3  C_ID_0001793786                      189                  0.0
# 4  C_ID_000183fdda                      137                  4.0
#
#    auth_category_1_mean  auth_category_2_1.0_mean  auth_category_2_2.0_mean  \
# 0              0.210526                  0.000000                  0.000000
# 1              0.016667                  0.783333                  0.000000
# 2              0.000000                  0.032258                  0.000000
# 3              0.000000                  0.042328                  0.359788
# 4              0.029197                  0.051095                  0.007299
#
#    auth_category_2_3.0_mean  auth_category_2_4.0_mean  \
# 0                  0.780702                       0.0
# 1                  0.000000                       0.0
# 2                  0.967742                       0.0
# 3                  0.063492                       0.0
# 4                  0.905109                       0.0
#
#    auth_category_2_5.0_mean  auth_category_3_A_mean          ...           \
# 0                  0.008772                     0.0          ...
# 1                  0.150000                     0.0          ...
# 2                  0.000000                     1.0          ...
# 3                  0.000000                     1.0          ...
# 4                  0.007299                     0.0          ...
#
#    auth_purchase_month_min  auth_purchase_month_std  auth_purchase_date_ptp  \
# 0                        1                 3.371490              32627654.0
# 1                        1                 4.895483              13110825.0
# 2                        1                 4.538017              34460275.0
# 3                        1                 2.301491              24487497.0
# 4                        1                 4.538289              15148616.0
#
#    auth_purchase_date_min  auth_purchase_date_max  auth_month_lag_mean  \
# 0            1.487081e+09            1.519708e+09            -5.798246
# 1            1.506638e+09            1.519748e+09            -1.825000
# 2            1.484411e+09            1.518871e+09            -4.983871
# 3            1.484994e+09            1.509481e+09            -3.301587
# 4            1.504444e+09            1.519592e+09            -2.284672
#
#    auth_month_lag_max  auth_month_lag_min  auth_month_lag_std  \
# 0                   0                 -12            3.441495
# 1                   0                  -5            1.294218
# 2                   0                 -13            4.248402
# 3                   0                  -9            2.301491
# 4                   0                  -5            1.782055
#
#    auth_month_diff_mean
# 0             10.605263
# 1             10.283333
# 2             10.661290
# 3             14.386243
# 4             10.503650
#
# [5 rows x 39 columns]

# %%
new = aggregate_transactions(new_transactions)
new.columns = ['new_' + c if c != 'card_id' else c for c in new.columns]

# %%
new.head()
# Out:
#            card_id  new_transactions_count  new_category_1_sum  \
# 0  C_ID_00007093c1                       2                   0
# 1  C_ID_0001238066                      26                   2
# 2  C_ID_0001506ef0                       2                   0
# 3  C_ID_0001793786                      31                   0
# 4  C_ID_000183fdda                      11                   0
#
#    new_category_1_mean  new_category_2_1.0_mean  new_category_2_2.0_mean  \
# 0             0.000000                 0.500000                 0.000000
# 1             0.076923                 0.769231                 0.000000
# 2             0.000000                 0.000000                 0.000000
# 3             0.000000                 0.483871                 0.258065
# 4             0.000000                 0.000000                 0.000000
#
#    new_category_2_3.0_mean  new_category_2_4.0_mean  new_category_2_5.0_mean  \
# 0                  0.50000                      0.0                 0.000000
# 1                  0.00000                      0.0                 0.115385
# 2                  1.00000                      0.0                 0.000000
# 3                  0.16129                      0.0                 0.032258
# 4                  1.00000                      0.0                 0.000000
#
#    new_category_3_A_mean         ...           new_purchase_month_min  \
# 0                    0.0         ...                                4
# 1                    0.0         ...                                3
# 2                    1.0         ...                                3
# 3                    1.0         ...                               11
# 4                    0.0         ...                                3
#
#    new_purchase_month_std  new_purchase_date_ptp  new_purchase_date_min  \
# 0                0.000000               537024.0           1.522754e+09
# 1                0.485165              5195343.0           1.519923e+09
# 2                0.000000               471152.0           1.521239e+09
# 3                0.475191              3981096.0           1.510761e+09
# 4                0.467099              5106807.0           1.519994e+09
#
#    new_purchase_date_max  new_month_lag_mean  new_month_lag_max  \
# 0           1.523291e+09            2.000000                  2
# 1           1.525118e+09            1.346154                  2
# 2           1.521710e+09            1.000000                  1
# 3           1.514742e+09            1.322581                  2
# 4           1.525100e+09            1.272727                  2
#
#    new_month_lag_min  new_month_lag_std  new_month_diff_mean
# 0                  2           0.000000            11.000000
# 1                  1           0.485165            10.192308
# 2                  1           0.000000            10.000000
# 3                  1           0.475191            14.032258
# 4                  1           0.467099            10.727273
#
# [5 rows x 39 columns]

# %%
def aggregate_per_month(history):
    grouped = history.groupby(['card_id', 'month_lag'])

    agg_func = {
            'purchase_amount': ['count', 'sum', 'mean', 'min', 'max', 'std'],
            'installments': ['count', 'sum', 'mean', 'min', 'max', 'std'],
            }

    intermediate_group = grouped.agg(agg_func)
    intermediate_group.columns = ['_'.join(col).strip() for col in intermediate_group.columns.values]
    intermediate_group.reset_index(inplace=True)

    final_group = intermediate_group.groupby('card_id').agg(['mean', 'std'])
    final_group.columns = ['_'.join(col).strip() for col in final_group.columns.values]
    final_group.reset_index(inplace=True)
    
    return final_group

# %%
final_group =  aggregate_per_month(authorized_transactions) 
final_group.head()
# Out:
#            card_id  month_lag_mean  month_lag_std  purchase_amount_count_mean  \
# 0  C_ID_00007093c1       -6.000000       3.894440                    8.769231
# 1  C_ID_0001238066       -2.500000       1.870829                   20.000000
# 2  C_ID_0001506ef0       -6.230769       4.225988                    4.769231
# 3  C_ID_0001793786       -4.500000       3.027650                   18.900000
# 4  C_ID_000183fdda       -2.500000       1.870829                   22.833333
#
#    purchase_amount_count_std  purchase_amount_sum_mean  \
# 0                   3.539158                 -4.803313
# 1                  11.696153                -11.776212
# 2                   4.342692                 -2.438161
# 3                  12.160501                 -2.496067
# 4                   7.167054                -11.316092
#
#    purchase_amount_sum_std  purchase_amount_mean_mean  \
# 0                 2.175011                  -0.536131
# 1                 6.676914                  -0.603215
# 2                 2.902502                  -0.446660
# 3                 4.018810                  -0.005687
# 4                 4.800612                  -0.489227
#
#    purchase_amount_mean_std  purchase_amount_min_mean          ...           \
# 0                  0.075418                 -0.702649          ...
# 1                  0.046045                 -0.730351          ...
# 2                  0.271125                 -0.725724          ...
# 3                  0.271221                 -0.646277          ...
# 4                  0.141015                 -0.728405          ...
#
#    installments_sum_mean  installments_sum_std  installments_mean_mean  \
# 0              11.307692              4.210792                1.369646
# 1              32.500000             24.501020                1.652873
# 2               0.000000              0.000000                0.000000
# 3               0.000000              0.000000                0.000000
# 4              40.833333             14.048725                1.834943
#
#    installments_mean_std  installments_min_mean  installments_min_std  \
# 0               0.423190               1.000000              0.000000
# 1               0.410539               0.666667              0.816497
# 2               0.000000               0.000000              0.000000
# 3               0.000000               0.000000              0.000000
# 4               0.362557               0.333333              1.032796
#
#    installments_max_mean  installments_max_std  installments_std_mean  \
# 0               2.538462              1.613246               0.625428
# 1               4.666667              2.875181               1.256525
# 2               0.000000              0.000000               0.000000
# 3               0.000000              0.000000               0.000000
# 4               9.166667              2.041241               2.144389
#
#    installments_std_std
# 0              0.675607
# 1              0.521292
# 2              0.000000
# 3              0.000000
# 4              0.665529
#
# [5 rows x 27 columns]

# %%
def successive_aggregates(df, field1, field2):
    t = df.groupby(['card_id', field1])[field2].mean()
    u = pd.DataFrame(t).reset_index().groupby('card_id')[field2].agg(['mean', 'min', 'max', 'std'])
    u.columns = [field1 + '_' + field2 + '_' + col for col in u.columns.values]
    u.reset_index(inplace=True)
    return u

# %%
additional_fields = successive_aggregates(new_transactions, 'category_1', 'purchase_amount')
additional_fields = additional_fields.merge(successive_aggregates(new_transactions, 'installments', 'purchase_amount'),
                                            on = 'card_id', how='left')
additional_fields = additional_fields.merge(successive_aggregates(new_transactions, 'city_id', 'purchase_amount'),
                                            on = 'card_id', how='left')
additional_fields = additional_fields.merge(successive_aggregates(new_transactions, 'category_1', 'installments'),
                                            on = 'card_id', how='left')

# %%
print(additional_fields.columns)
additional_fields.head()
# Out:
# Index(['card_id', 'category_1_purchase_amount_mean',
#        'category_1_purchase_amount_min', 'category_1_purchase_amount_max',
#        'category_1_purchase_amount_std', 'installments_purchase_amount_mean',
#        'installments_purchase_amount_min', 'installments_purchase_amount_max',
#        'installments_purchase_amount_std', 'city_id_purchase_amount_mean',
#        'city_id_purchase_amount_min', 'city_id_purchase_amount_max',
#        'city_id_purchase_amount_std', 'category_1_installments_mean',
#        'category_1_installments_min', 'category_1_installments_max',
#        'category_1_installments_std'],
#       dtype='object')
#            card_id  category_1_purchase_amount_mean  \
# 0  C_ID_00007093c1                        -0.664062
# 1  C_ID_0001238066                        -0.607422
# 2  C_ID_0001506ef0                        -0.723633
# 3  C_ID_0001793786                        -0.007385
# 4  C_ID_000183fdda                        -0.599121
#
#    category_1_purchase_amount_min  category_1_purchase_amount_max  \
# 0                       -0.664062                       -0.664062
# 1                       -0.650391                       -0.564453
# 2                       -0.723633                       -0.723633
# 3                       -0.007385                       -0.007385
# 4                       -0.599121                       -0.599121
#
#    category_1_purchase_amount_std  installments_purchase_amount_mean  \
# 0                             NaN                          -0.664062
# 1                         0.06076                          -0.423828
# 2                             NaN                          -0.723633
# 3                             NaN                          -0.007385
# 4                             NaN                          -0.491211
#
#    installments_purchase_amount_min  installments_purchase_amount_max  \
# 0                         -0.664062                         -0.664062
# 1                         -0.625977                         -0.151978
# 2                         -0.723633                         -0.723633
# 3                         -0.007385                         -0.007385
# 4                         -0.696289                         -0.107666
#
#    installments_purchase_amount_std  city_id_purchase_amount_mean  \
# 0                               NaN                     -0.664062
# 1                          0.222046                     -0.558105
# 2                               NaN                     -0.723633
# 3                               NaN                     -0.247070
# 4                          0.233887                     -0.572266
#
#    city_id_purchase_amount_min  city_id_purchase_amount_max  \
# 0                    -0.671875                    -0.656738
# 1                    -0.666992                    -0.472168
# 2                    -0.723633                    -0.723633
# 3                    -0.572754                     0.249268
# 4                    -0.604980                    -0.539062
#
#    city_id_purchase_amount_std  category_1_installments_mean  \
# 0                     0.010704                      1.000000
# 1                     0.072632                      2.479167
# 2                          NaN                      0.000000
# 3                     0.346924                      0.000000
# 4                     0.046600                      1.454545
#
#    category_1_installments_min  category_1_installments_max  \
# 0                     1.000000                     1.000000
# 1                     1.458333                     3.500000
# 2                     0.000000                     0.000000
# 3                     0.000000                     0.000000
# 4                     1.454545                     1.454545
#
#    category_1_installments_std
# 0                          NaN
# 1                     1.443676
# 2                          NaN
# 3                          NaN
# 4                          NaN

# %% [markdown]
# # Training the model

# %%
# merge all the dataframes
train = pd.merge(train, history, on='card_id', how='left')
test = pd.merge(test, history, on='card_id', how='left')

train = pd.merge(train, authorized, on='card_id', how='left')
test = pd.merge(test, authorized, on='card_id', how='left')

train = pd.merge(train, new, on='card_id', how='left')
test = pd.merge(test, new, on='card_id', how='left')

train = pd.merge(train, final_group, on='card_id', how='left')
test = pd.merge(test, final_group, on='card_id', how='left')

train = pd.merge(train, auth_mean, on='card_id', how='left')
test = pd.merge(test, auth_mean, on='card_id', how='left')

train = pd.merge(train, additional_fields, on='card_id', how='left')
test = pd.merge(test, additional_fields, on='card_id', how='left')

# %%
print(train.shape)
train.columns
# Out:
# (201917, 163)
# Index(['first_active_month', 'card_id', 'feature_1', 'feature_2', 'feature_3',
#        'elapsed_time', 'hist_transactions_count', 'hist_category_1_sum',
#        'hist_category_1_mean', 'hist_category_2_1.0_mean',
#        ...
#        'installments_purchase_amount_max', 'installments_purchase_amount_std',
#        'city_id_purchase_amount_mean', 'city_id_purchase_amount_min',
#        'city_id_purchase_amount_max', 'city_id_purchase_amount_std',
#        'category_1_installments_mean', 'category_1_installments_min',
#        'category_1_installments_max', 'category_1_installments_std'],
#       dtype='object', length=163)

# %%
test.to_csv('final_test.csv')
train.to_csv('final_train.csv')

# %%
train = pd.read_csv('final_train.csv', index_col=0)
test = pd.read_csv('final_test.csv', index_col=0)
target = pd.read_csv("train.csv")['target']

# %%
train.shape
# Out:
# (201917, 165)

# %%
train["elapsed_mon"] = pd.cut(train.elapsed_time, np.arange(0, 2290, 24*10), labels=np.arange(9))

# %%
test["elapsed_mon"] = pd.cut(test.elapsed_time, np.arange(0, 2290, 24*10), labels=np.arange(9))

# %%
train["elapsed_hour"] = train.elapsed_time.map(lambda x: x%24//2)

# %%
test["elapsed_hour"] = test.elapsed_time.map(lambda x: x%24//2)

# %%
train.to_csv("final_train.csv")
test.to_csv("final_test.csv")
target.to_csv("target.csv")

# %%
train_without31 = train[(target>-30)]
test_without31 = test[(target>-30)]
target_without31 = target[(target>-30)]

# %%
train_without31.to_csv("final_train_without31.csv")
test_without31.to_csv("final_test_without31.csv")
target_without31.to_csv("target_without31.csv")

# %%
target_less31_bool = target<-30
target_less31_bool.to_csv("target_less31_bool.csv")

# %%
features = [c for c in train.columns if c not in ['card_id', 'first_active_month']]
categorical_feats = ['feature_1','feature_2', 'feature_3',"elapsed_mon", "elapsed_hour"]

# %% [markdown]
# ## lightgbm

# %%
train = pd.read_csv('final_train.csv', index_col=0)
test = pd.read_csv('final_test.csv', index_col=0)
target = pd.read_csv("train.csv")['target']

# %%
param = {'num_leaves': 111,
         'min_data_in_leaf': 149, 
         'objective':'regression',
         'max_depth': 9,
         'learning_rate': 0.005,
         "boosting": "gbdt",
         "feature_fraction": 0.7522,
         "bagging_freq": 1,
         "bagging_fraction": 0.7083 ,
         "bagging_seed": 11,
         "metric": 'rmse',
         "lambda_l1": 0.2634,
         "random_state": 133,
         "verbosity": -1}
# https://www.kaggle.com/fabiendaniel/hyperparameter-tuning

# %%
folds = KFold(n_splits=5, shuffle=True, random_state=15)
oof = np.zeros(len(train))
predictions = np.zeros(len(test))
start = time.time()
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    print("fold n {}".format(fold_))
    trn_data = lgb.Dataset(train.iloc[trn_idx][features],
                           label=target.iloc[trn_idx],
                           categorical_feature=categorical_feats
                          )
    val_data = lgb.Dataset(train.iloc[val_idx][features],
                           label=target.iloc[val_idx],
                           categorical_feature=categorical_feats
                          )

    num_round = 10000
    clf = lgb.train(param,
                    trn_data,
                    num_round,
                    valid_sets = [trn_data, val_data],
                    verbose_eval=100,
                    early_stopping_rounds = 200)
    
    oof[val_idx] = clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
#     fold_importance_df = pd.DataFrame()
#     fold_importance_df["feature"] = features
#     fold_importance_df["importance"] = clf.feature_importance()
#     fold_importance_df["fold"] = fold_ + 1
#     feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(mean_squared_error(oof, target)**0.5))
# Out:
# fold n 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3
3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.6869	valid_1's rmse: 3.88011
# [200]	training's rmse: 3.61585	valid_1's rmse: 3.83253
# [300]	training's rmse: 3.57133	valid_1's rmse: 3.80923
# [400]	training's rmse: 3.53853	valid_1's rmse: 3.79718
# [500]	training's rmse: 3.51341	valid_1's rmse: 3.7908
# [600]	training's rmse: 3.49404	valid_1's rmse: 3.78715
# [700]	training's rmse: 3.47684	valid_1's rmse: 3.78482
# [800]	training's rmse: 3.46154	valid_1's rmse: 3.78304
# [900]	training's rmse: 3.44756	valid_1's rmse: 3.78197
# [1000]	training's rmse: 3.43387	valid_1's rmse: 3.78129
# [1100]	training's rmse: 3.42094	valid_1's rmse: 3.78087
# [1200]	training's rmse: 3.40829	valid_1's rmse: 3.78032
# [1300]	training's rmse: 3.39665	valid_1's rmse: 3.77992
# [1400]	training's rmse: 3.38469	valid_1's rmse: 3.78002
# Early stopping, best iteration is:
# [1292]	training's rmse: 3.39758	valid_1's rmse: 3.77983
# fold n 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 3.73234	valid_1's rmse: 3.69365
# [200]	training's rmse: 3.6598	valid_1's rmse: 3.65168
# [300]	training's rmse: 3.61415	valid_1's rmse: 3.6329
# [400]	training's rmse: 3.58196	valid_1's rmse: 3.62363
# [500]	training's rmse: 3.55761	valid_1's rmse: 3.61843
# [600]	training's rmse: 3.53729	valid_1's rmse: 3.61581
# [700]	training's rmse: 3.52058	valid_1's rmse: 3.61413
# [800]	training's rmse: 3.5051	valid_1's rmse: 3.61337
# [900]	training's rmse: 3.49116	valid_1's rmse: 3.61256
# [1000]	training's rmse: 3.47759	valid_1's rmse: 3.61197
# [1100]	training's rmse: 3.46456	valid_1's rmse: 3.6115
# [1200]	training's rmse: 3.45262	valid_1's rmse: 3.61165
# [1300]	training's rmse: 3.44076	valid_1's rmse: 3.61164
# Early stopping, best iteration is:
# [1109]	training's rmse: 3.46366	valid_1's rmse: 3.6115
# CV score: 3.65484

# %%
np.save("predictions_lgbm_5.npy", predictions)

# %%
np.argsort(clf.predict(train[features], num_iteration=clf.best_iteration))

# %%
target[np.argsort(clf.predict(train[features], num_iteration=clf.best_iteration))][:1000]
# Out:
# 171585   -33.219281
# 42753    -33.219281
# 25880    -33.219281
# 25347    -33.219281
# 161607   -33.219281
# 13101    -33.219281
# 17724    -33.219281
# 128262   -33.219281
# 156077   -33.219281
# 12602    -33.219281
# 135378   -33.219281
# 159259   -33.219281
# 60491      0.632296
# 2170      -0.147904
# 47385    -33.219281
# 88227    -33.219281
# 160797   -33.219281
# 148428   -33.219281
# 9528     -33.219281
# 22633    -33.219281
# 16989    -33.219281
# 73174    -33.219281
# 160204   -33.219281
# 156580   -33.219281
# 186912   -33.219281
# 179088   -33.219281
# 65839    -33.219281
# 85329    -33.219281
# 139384   -33.219281
# 182878   -33.219281
#             ...
# 198153     2.488296
# 150195     1.031589
# 200806    -1.234421
# 35182    -33.219281
# 126140   -33.219281
# 142043   -33.219281
# 11510     -0.894558
# 3271      -4.014950
# 51317     -1.155588
# 85665    -33.219281
# 49246      0.080121
# 114335    -1.000307
# 84367     -0.883689
# 167471     0.746667
# 153398     0.207543
# 95223    -33.219281
# 141269   -33.219281
# 41212    -33.219281
# 182253    -0.077918
# 148484     1.542831
# 37668      0.963340
# 62032     -0.521628
# 191342     0.093959
# 147816   -33.219281
# 149769    -5.257378
# 41614    -33.219281
# 137761   -33.219281
# 192046     0.897451
# 197237    -3.251441
# 63849    -33.219281
# Name: target, Length: 1000, dtype: float64

# %%
(target<-10).sum()
# Out:
# 2264

# %%
(predictions).std()
# Out:
# 1.1560921306116398

# %%
target[target>-20].std()
# Out:
# 1.7177929279593622

# %%
sns.distplot(predictions)

# %%
joblib.dump(clf,'lgb_5.pkl')
# Out:
# ['lgb_5.pkl']

# %%
folds = KFold(n_splits=5, shuffle=True, random_state=15)
oof = np.zeros(len(train_without31))
predictions = np.zeros(len(test))
start = time.time()
feature_importance_df = pd.DataFrame()

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train_without31.values, target_without31.values)):
    print("fold n {}".format(fold_))
    trn_data = lgb.Dataset(train_without31.iloc[trn_idx][features],
                           label=target_without31.iloc[trn_idx],
                           categorical_feature=categorical_feats
                          )
    val_data = lgb.Dataset(train_without31.iloc[val_idx][features],
                           label=target_without31.iloc[val_idx],
                           categorical_feature=categorical_feats
                          )

    num_round = 10000
    clf = lgb.train(param,
                    trn_data,
                    num_round,
                    valid_sets = [trn_data, val_data],
                    verbose_eval=100,
                    early_stopping_rounds = 200)
    
    oof[val_idx] = clf.predict(train_without31.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = features
    fold_importance_df["importance"] = clf.feature_importance()
    fold_importance_df["fold"] = fold_ + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits

print("CV score: {:<8.5f}".format(mean_squared_error(oof, target_without31)**0.5))
# Out:
# fold n 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.62766	valid_1's rmse: 1.64064
# [200]	training's rmse: 1.58421	valid_1's rmse: 1.60518
# [300]	training's rmse: 1.55999	valid_1's rmse: 1.58792
# [400]	training's rmse: 1.54432	valid_1's rmse: 1.57858
# [500]	training's rmse: 1.53269	valid_1's rmse: 1.57309
# [600]	training's rmse: 1.52331	valid_1's rmse: 1.5696
# [700]	training's rmse: 1.51547	valid_1's rmse: 1.5673
# [800]	training's rmse: 1.50844	valid_1's rmse: 1.56569
# [900]	training's rmse: 1.5026	valid_1's rmse: 1.56455
# [1000]	training's rmse: 1.49733	valid_1's rmse: 1.56368
# [1100]	training's rmse: 1.49255	valid_1's rmse: 1.56314
# [1200]	training's rmse: 1.4882	valid_1's rmse: 1.56273
# [1300]	training's rmse: 1.48421	valid_1's rmse: 1.56237
# [1400]	training's rmse: 1.48021	valid_1's rmse: 1.56216
# [1500]	training's rmse: 1.47668	valid_1's rmse: 1.56203
# [1600]	training's rmse: 1.47293	valid_1's rmse: 1.5619
# [1700]	training's rmse: 1.46971	valid_1's rmse: 1.56179
# [1800]	training's rmse: 1.46627	valid_1's rmse: 1.5617
# [1900]	training's rmse: 1.4629	valid_1's rmse: 1.56166
# [2000]	training's rmse: 1.45936	valid_1's rmse: 1.56165
# [2100]	training's rmse: 1.45618	valid_1's rmse: 1.56159
# [2200]	training's rmse: 1.45293	valid_1's rmse: 1.56152
# [2300]	training's rmse: 1.44958	valid_1's rmse: 1.56149
# [2400]	training's rmse: 1.44615	valid_1's rmse: 1.56149
# [2500]	training's rmse: 1.44298	valid_1's rmse: 1.56155
# Early stopping, best iteration is:
# [2331]	training's rmse: 1.44856	valid_1's rmse: 1.56147
# fold n 1
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.62858	valid_1's rmse: 1.63925
# [200]	training's rmse: 1.58535	valid_1's rmse: 1.60259
# [300]	training's rmse: 1.56117	valid_1's rmse: 1.58472
# [400]	training's rmse: 1.54551	valid_1's rmse: 1.57502
# [500]	training's rmse: 1.53392	valid_1's rmse: 1.56944
# [600]	training's rmse: 1.52445	valid_1's rmse: 1.56591
# [700]	training's rmse: 1.51641	valid_1's rmse: 1.56353
# [800]	training's rmse: 1.50964	valid_1's rmse: 1.56195
# [900]	training's rmse: 1.50368	valid_1's rmse: 1.56073
# [1000]	training's rmse: 1.49832	valid_1's rmse: 1.5599
# [1100]	training's rmse: 1.49385	valid_1's rmse: 1.55927
# [1200]	training's rmse: 1.48934	valid_1's rmse: 1.55873
# [1300]	training's rmse: 1.48528	valid_1's rmse: 1.55839
# [1400]	training's rmse: 1.48112	valid_1's rmse: 1.55807
# [1500]	training's rmse: 1.47724	valid_1's rmse: 1.55788
# [1600]	training's rmse: 1.47366	valid_1's rmse: 1.55775
# [1700]	training's rmse: 1.47013	valid_1's rmse: 1.5576
# [1800]	training's rmse: 1.4665	valid_1's rmse: 1.55755
# [1900]	training's rmse: 1.46299	valid_1's rmse: 1.55748
# [2000]	training's rmse: 1.45958	valid_1's rmse: 1.55744
# [2100]	training's rmse: 1.45623	valid_1's rmse: 1.55743
# [2200]	training's rmse: 1.45271	valid_1's rmse: 1.55744
# Early stopping, best iteration is:
# [2033]	training's rmse: 1.45849	valid_1's rmse: 1.55741
# fold n 2
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.63345	valid_1's rmse: 1.61821
# [200]	training's rmse: 1.59024	valid_1's rmse: 1.58141
# [300]	training's rmse: 1.5659	valid_1's rmse: 1.56351
# [400]	training's rmse: 1.55011	valid_1's rmse: 1.55416
# [500]	training's rmse: 1.53845	valid_1's rmse: 1.54863
# [600]	training's rmse: 1.52917	valid_1's rmse: 1.54517
# [700]	training's rmse: 1.52123	valid_1's rmse: 1.54283
# [800]	training's rmse: 1.51441	valid_1's rmse: 1.54126
# [900]	training's rmse: 1.50875	valid_1's rmse: 1.54011
# [1000]	training's rmse: 1.50356	valid_1's rmse: 1.53926
# [1100]	training's rmse: 1.49865	valid_1's rmse: 1.53866
# [1200]	training's rmse: 1.49409	valid_1's rmse: 1.5382
# [1300]	training's rmse: 1.48993	valid_1's rmse: 1.53788
# [1400]	training's rmse: 1.48591	valid_1's rmse: 1.53752
# [1500]	training's rmse: 1.48195	valid_1's rmse: 1.5373
# [1600]	training's rmse: 1.47814	valid_1's rmse: 1.53714
# [1700]	training's rmse: 1.47442	valid_1's rmse: 1.53703
# [1800]	training's rmse: 1.47095	valid_1's rmse: 1.53697
# [1900]	training's rmse: 1.4673	valid_1's rmse: 1.53693
# [2000]	training's rmse: 1.46402	valid_1's rmse: 1.5369
# [2100]	training's rmse: 1.46087	valid_1's rmse: 1.53688
# Early stopping, best iteration is:
# [1926]	training's rmse: 1.46636	valid_1's rmse: 1.53686
# fold n 3
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.62861	valid_1's rmse: 1.63846
# [200]	training's rmse: 1.5856	valid_1's rmse: 1.60158
# [300]	training's rmse: 1.5613	valid_1's rmse: 1.58364
# [400]	training's rmse: 1.54552	valid_1's rmse: 1.57409
# [500]	training's rmse: 1.53375	valid_1's rmse: 1.56842
# [600]	training's rmse: 1.52432	valid_1's rmse: 1.56486
# [700]	training's rmse: 1.51646	valid_1's rmse: 1.5625
# [800]	training's rmse: 1.50962	valid_1's rmse: 1.56093
# [900]	training's rmse: 1.50404	valid_1's rmse: 1.55991
# [1000]	training's rmse: 1.49896	valid_1's rmse: 1.55913
# [1100]	training's rmse: 1.4943	valid_1's rmse: 1.55863
# [1200]	training's rmse: 1.48989	valid_1's rmse: 1.55822
# [1300]	training's rmse: 1.48561	valid_1's rmse: 1.55794
# [1400]	training's rmse: 1.4816	valid_1's rmse: 1.55778
# [1500]	training's rmse: 1.47782	valid_1's rmse: 1.55756
# [1600]	training's rmse: 1.47429	valid_1's rmse: 1.55747
# [1700]	training's rmse: 1.47079	valid_1's rmse: 1.55734
# [1800]	training's rmse: 1.46731	valid_1's rmse: 1.55727
# [1900]	training's rmse: 1.46385	valid_1's rmse: 1.55729
# [2000]	training's rmse: 1.46036	valid_1's rmse: 1.55721
# [2100]	training's rmse: 1.45705	valid_1's rmse: 1.5572
# [2200]	training's rmse: 1.45373	valid_1's rmse: 1.5572
# Early stopping, best iteration is:
# [2042]	training's rmse: 1.45892	valid_1's rmse: 1.55717
# fold n 4
# Training until validation scores don't improve for 200 rounds.
# [100]	training's rmse: 1.62742	valid_1's rmse: 1.64278
# [200]	training's rmse: 1.58427	valid_1's rmse: 1.60577
# [300]	training's rmse: 1.56004	valid_1's rmse: 1.58779
# [400]	training's rmse: 1.54434	valid_1's rmse: 1.57814
# [500]	training's rmse: 1.53279	valid_1's rmse: 1.57241
# [600]	training's rmse: 1.52333	valid_1's rmse: 1.5688
# [700]	training's rmse: 1.51536	valid_1's rmse: 1.56627
# [800]	training's rmse: 1.50863	valid_1's rmse: 1.56462
# [900]	training's rmse: 1.50267	valid_1's rmse: 1.56342
# [1000]	training's rmse: 1.49722	valid_1's rmse: 1.56256
# [1100]	training's rmse: 1.49213	valid_1's rmse: 1.56191
# [1200]	training's rmse: 1.48759	valid_1's rmse: 1.5614
# [1300]	training's rmse: 1.48356	valid_1's rmse: 1.56103
# [1400]	training's rmse: 1.47938	valid_1's rmse: 1.56072
# [1500]	training's rmse: 1.47541	valid_1's rmse: 1.56042
# [1600]	training's rmse: 1.47169	valid_1's rmse: 1.56026
# [1700]	training's rmse: 1.46822	valid_1's rmse: 1.56017
# [1800]	training's rmse: 1.46456	valid_1's rmse: 1.56011
# [1900]	training's rmse: 1.46102	valid_1's rmse: 1.56004
# [2000]	training's rmse: 1.45776	valid_1's rmse: 1.56003
# [2100]	training's rmse: 1.45451	valid_1's rmse: 1.55999
# [2200]	training's rmse: 1.45115	valid_1's rmse: 1.55999
# [2300]	training's rmse: 1.44763	valid_1's rmse: 1.55992
# [2400]	training's rmse: 1.44419	valid_1's rmse: 1.55993
# [2500]	training's rmse: 1.44077	valid_1's rmse: 1.55993
# Early stopping, best iteration is:
# [2368]	training's rmse: 1.44528	valid_1's rmse: 1.55989
# CV score: 1.55459

# %%
np.save("predictions_lgbm_without_31_1.npy", predictions)

# %%
predictions
# Out:
# array([-0.53107655, -0.30205992, -0.70470531, ...,  1.1530389 ,
#        -0.78804415,  0.2466566 ])

# %%
np.load("predictions_lgbm_without_31_1.npy").std()
# Out:
# 0.720805856981275

# %%
sns.distplot(predictions)

# %%
joblib.dump(clf,'lgb_without_31_1.pkl')
# Out:
# ['lgb_without_31_1.pkl']

# %% [markdown]
# ## Classification

# %%
train = pd.read_csv('final_train.csv', index_col=0)
test = pd.read_csv('final_test.csv', index_col=0)
target = pd.read_csv("target_less31_bool.csv", index_col=0, header=None).astype("int")[1]

# %%
train = reduce_mem_usage(train)
test = reduce_mem_usage(test)
# Out:
# Mem. usage decreased to 70.29 Mb (72.5% reduction)
# Mem. usage decreased to 42.44 Mb (72.9% reduction)

# %%
features = [c for c in train.columns if c not in ['card_id', 'first_active_month']]
categorical_feats = ['feature_1','feature_2', 'feature_3',"elapsed_mon", "elapsed_hour"]

# %%
train_cla90 = train.copy()
target_cla90 = target.copy()
train_31 = train[pd.read_csv("train.csv").target<-30]
target_31 = target[pd.read_csv("train.csv").target<-30]
for i in range(90):
    train_cla90 = pd.concat([train_cla90, train_31], axis=0)
    target_cla90 = pd.concat([target_cla90, target_31], axis=0)
    if i%10 ==0:
        print(i)
print("Done!")
del train_31
del target_31
# Out:
# 0
# 10
# 20
# 30
# 40
# 50
# 60
# 70
# 80
# Done!

# %%
train_cla90 = reduce_mem_usage(train_cla90)
# Out:
# Mem. usage decreased to 139.43 Mb (72.5% reduction)

# %%
train_cla90.to_csv("train_cla90.csv")
target_cla90.to_csv("target_cla90.csv")

# %%
# x_train, x_test, y_train, y_test = train_test_split(train[features], target_1)

# %%
# def fill_nan(df):
#     nan_count =  df.isna().sum(axis=0)
#     nan_cols = nan_count[nan_count !=0].index
#     for c in nan_cols:
#         df[c].fillna(df[c][df[c].notna()].mean(), inplace=True)

# %%
# fill_nan(x_train)
# fill_nan(x_test)

# %%
param = {'num_leaves': 111,
         'min_data_in_leaf': 149, 
         'objective':'binary',
         'max_depth': 9,
         'learning_rate': 0.005,
         "boosting": "gbdt",
         "feature_fraction": 0.7522,
         "bagging_freq": 1,
         "bagging_fraction": 0.7083 ,
         "bagging_seed": 11,
         "metric": 'auc',
         "lambda_l1": 0.2634,
         "random_state": 36,
         "verbosity": -1}

# %%
param = {'num_leaves': 111,
         'min_data_in_leaf': 149, 
         'objective':'regression',
         'max_depth': 9,
         'learning_rate': 0.005,
         "boosting": "gbdt",
         "feature_fraction": 0.7522,
         "bagging_freq": 1,
         "bagging_fraction": 0.7083 ,
         "bagging_seed": 11,
         "metric": 'rmse',
         "lambda_l1": 0.2634,
         "random_state": 36,
         "verbosity": -1}

# %%
# param = {'num_leaves': 197,
#          'min_data_in_leaf': 93, 
#          'objective':'binary',
#          'max_depth': 11,
#          'learning_rate': 0.01,
#          "boosting": "gbdt",
#          "feature_fraction": 0.7522,
#          "bagging_freq": 1,
#          "bagging_fraction": 0.7083 ,
#          "bagging_seed": 11,
#          "metric": 'binary_logloss',
#          "lambda_l1": 0.2634,
#          "random_state": 133,
#          "verbosity": -1}

# %%
train = pd.read_csv('train_cla90.csv', index_col=0)
test = pd.read_csv('final_test.csv', index_col=0)
target = pd.read_csv("target_cla90.csv", index_col=0).target

# %%
train = pd.read_csv('final_train.csv', index_col=0)
test = pd.read_csv('final_test.csv', index_col=0)
target = pd.read_csv("target_less31_bool.csv", index_col=0, header=None).astype("int")[1]

# %%
train, val_train, target,  val_target =  train_test_split(train, target, \
                                            test_size = 0.3, random_state=37, shuffle=True)

# %%
train.shape, target.shape, val_train.shape, val_target.shape
# Out:
# ((280382, 165), (280382,), (120165, 165), (120165,))

# %%
(target==0).sum()/(target==1).sum()
# Out:
# 0.9948205328874817

# %%
folds = KFold(n_splits=5, shuffle=True, random_state=127)
oof = np.zeros(len(train))
predictions = np.zeros(len(test))
start = time.time()
# feature_importance_df = pd.DataFrame()
clfs = []

for fold_, (trn_idx, val_idx) in enumerate(folds.split(train.values, target.values)):
    print("fold n {}".format(fold_))
    trn_data = lgb.Dataset(train.iloc[trn_idx][features],
                           label=target.iloc[trn_idx],
                           categorical_feature=categorical_feats
                          )
    val_data = lgb.Dataset(train.iloc[val_idx][features],
                           label=target.iloc[val_idx],
                           categorical_feature=categorical_feats
                          )

    num_round = 5000
    clf = lgb.train(param,
                    trn_data,
                    num_round,
                    valid_sets = [trn_data, val_data],
                    verbose_eval=100,
                    early_stopping_rounds = 200)
    
    oof[val_idx] = clf.predict(train.iloc[val_idx][features], num_iteration=clf.best_iteration)
    
#     fold_importance_df = pd.DataFrame()
#     fold_importance_df["feature"] = features
#     fold_importance_df["importance"] = clf.feature_importance()
#     fold_importance_df["fold"] = fold_ + 1
#     feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    
    predictions += clf.predict(test[features], num_iteration=clf.best_iteration) / folds.n_splits
    clfs.append(clf)

print("CV score: {:<8.5f}".format(mean_squared_error(oof, target)**0.5))
# Out:
# fold n 0
# Training until validation scores don't improve for 200 rounds.
# [100]	training's auc: 0.95193	valid_1's auc: 0.948917
# [200]	training's auc: 0.95724	valid_1's auc: 0.954276
# [300]	training's auc: 0.962307	valid_1's auc: 0.959356
# [400]	training's auc: 0.967153	valid_1's auc: 0.964168
# [500]	training's auc: 0.971056	valid_1's auc: 0.968093
# [600]	training's auc: 0.974529	valid_1's auc: 0.971599
# [700]	training's auc: 0.977612	valid_1's auc: 0.974768
# [800]	training's auc: 0.980113	valid_1's auc: 0.97733
# [900]	training's auc: 0.982342	valid_1's auc: 0.979613
# [1000]	training's auc: 0.983879	valid_1's auc: 0.981188
np.save("cla_auc_1.npy", pr)

# %%
target_bool = (pd.read_csv("train.csv").target<-31).astype(int)

# %%
# clfs = joblib.load('clafs_logloss6.pkl')

# %%
pr = sum([clf.predict(pd.read_csv("final_train.csv")[features], \
                      num_iteration=clf.best_iteration)/len(clfs) for clf in clfs])

# %%
confusion_matrix(pr>0.908, target_bool)
# Out:
# array([[199653,     23],
#        [    57,   2184]])

# %%
pr_test = sum([clf.predict(pd.read_csv("final_test.csv")[features], \
                      num_iteration=clf.best_iteration)/len(clfs) for clf in clfs])

# %%
(pd.read_csv("train.csv").target<-30).sum()/len(pd.read_csv("train.csv"))*len(pd.read_csv("test.csv"))
# Out:
# 1351.2282819178176

# %%
(pr_test>0.908).sum()
# Out:
# 122

# %%
submit_with_lgbm(pr_test>0.908,"submission15_908_.csv")

# %%
pr_test[pr_test.argsort()][::-1][1351]
# Out:
# 0.6440641132742975

# %%
(pr_test>0.6441).sum()
# Out:
# 1351

# %%
submit_with_lgbm(pr_test>0.6441,"submission15_6441_.csv")

# %%
submit_with_lgbm(pr_test-1000,"submission16_without_31.csv")

# %%
pd.read_csv("submission16_without_31.csv")
# Out:
#                 card_id    target
# 0       C_ID_0ab67a22ab -0.531077
# 1       C_ID_130fd0cbdd -0.302060
# 2       C_ID_b709037bc5 -0.704705
# 3       C_ID_d27d835a9f -0.134831
# 4       C_ID_2b5e3df5c2 -1.387117
# 5       C_ID_5814b4f13c  0.598820
# 6       C_ID_a1b3c75277  0.245804
# 7       C_ID_f7cada36d3  1.022977
# 8       C_ID_9d2bc8dfc4 -0.603376
# 9       C_ID_6d8dba8475 -0.366050
# 10      C_ID_4859ac9ed5 -0.597931
# 11      C_ID_0e281e8ad6  0.147456
# 12      C_ID_8375dfdaa2  0.188012
# 13      C_ID_79d149c008 -0.008885
# 14      C_ID_7f1041e8e1 -0.181240
# 15      C_ID_f72513589e  0.920733
# 16      C_ID_a7f2d6984e  0.604629
# 17      C_ID_15489b42d3 -0.029713
# 18      C_ID_e457bbd71d  0.209491
# 19      C_ID_3f74e10c7e -0.193779
# 20      C_ID_48243da9c4  0.198142
# 21      C_ID_7ea1fcf117 -0.701705
# 22      C_ID_22e4a47c72  1.361770
# 23      C_ID_5d30729184  0.288002
# 24      C_ID_b54cfad8b2 -0.119857
# 25      C_ID_4b82e26faa  0.564413
# 26      C_ID_60a453531a -0.798946
# 27      C_ID_0c9315feec -0.415153
# 28      C_ID_1e28804d36 -0.090189
# 29      C_ID_68de79f7e2 -0.620357
# ...                 ...       ...
# 123593  C_ID_cd42a5db89 -0.330451
# 123594  C_ID_715b9a183d -1.365484
# 123595  C_ID_9b25df3309  0.024390
# 123596  C_ID_043b3c2ccd  1.233960
# 123597  C_ID_7685eae7b2 -0.719889
# 123598  C_ID_7ee1a21a95 -0.485945
# 123599  C_ID_2bf12fed6b  0.559111
# 123600  C_ID_2932a6ea37  0.000631
# 123601  C_ID_cc33d0d508 -1.459526
# 123602  C_ID_8852708dcb -0.238808
# 123603  C_ID_c3e88ef62d  0.041005
# 123604  C_ID_650557248c  0.848694
# 123605  C_ID_f14af9cb56 -0.773060
# 123606  C_ID_068dcf31e8 -0.313493
# 123607  C_ID_6659f4625a  0.776249
# 123608  C_ID_dc842bba27 -0.427203
# 123609  C_ID_bd625edce0 -0.025045
# 123610  C_ID_278446cc2f  0.382404
# 123611  C_ID_ad358eb92e -1.067466
# 123612  C_ID_7d9bcec574 -0.732213
# 123613  C_ID_b588b35e15  0.081244
# 123614  C_ID_7147e348c3  1.059848
# 123615  C_ID_727d3ec5da -0.970927
# 123616  C_ID_107d93e20c  1.646668
# 123617  C_ID_0e74bd4966  0.669259
# 123618  C_ID_7a239d2eda  1.205847
# 123619  C_ID_75ace375ae -0.467611
# 123620  C_ID_21d56d950c  1.153039
# 123621  C_ID_6c46fc5a9d -0.788044
# 123622  C_ID_87e7979a5f  0.246657
#
# [123623 rows x 2 columns]

# %%
(0.908+0.6441)/2
# Out:
# 0.77605

# %%
(pr_test>0.77605).sum()
# Out:
# 631

# %%
submit_with_lgbm(pr_test>0.77605,"submission15_77605_.csv")

# %%
b= 10000
for i in np.arange(0.89, 0.91, 0.0001):
    c =  confusion_matrix(pr>i, target_bool)
    if (c[0][1]+c[1][0]) < b: 
        b = (c[0][1]+c[1][0])
        t=i

# %%
b, t
# Out:
# (80, 0.907999999999998)

# %%
pd.read_csv("train.csv").target[np.argsort(pr)[::-1]]
# Out:
# 25347    -33.219281
# 13101    -33.219281
# 100443   -33.219281
# 118541   -33.219281
# 197168   -33.219281
# 15807    -33.219281
# 89291    -33.219281
# 36224    -33.219281
# 162154   -33.219281
# 171585   -33.219281
# 3656     -33.219281
# 88034    -33.219281
# 183813   -33.219281
# 47385    -33.219281
# 25880    -33.219281
# 63849    -33.219281
# 134290   -33.219281
# 104394   -33.219281
# 83942    -33.219281
# 190324   -33.219281
# 16989    -33.219281
# 12602    -33.219281
# 33388    -33.219281
# 97496    -33.219281
# 176594   -33.219281
# 25272    -33.219281
# 132502   -33.219281
# 48324    -33.219281
# 69788    -33.219281
# 179088   -33.219281
#             ...
# 23877      0.941123
# 198710     0.230401
# 18784      1.160850
# 194986    -2.041701
# 64329     -0.300675
# 171295    -0.257652
# 91308     -0.199818
# 102229    -0.745523
# 88279      0.735475
# 97079      0.760579
# 194670    -0.083835
# 130188     1.806870
# 167216     0.771017
# 116305     0.091373
# 143408    -0.651277
# 37392      0.828133
# 19655      0.183249
# 189333    -1.176749
# 74027      5.005339
# 161217    -0.885729
# 53967     -1.789739
# 29187      0.652966
# 169502    -0.163120
# 107971     0.573151
# 31477      1.178895
# 22968     -1.168072
# 127530     1.359089
# 179993     4.210160
# 92316     -1.350069
# 120533    -1.902051
# Name: target, Length: 201917, dtype: float64

# %%
sns.distplot(predictions)

# %%
(predictions>0.8907).sum()
# Out:
# 1171

# %%
predictions[predictions.argsort()][::-1][1351]
# Out:
# 0.07951007884537675

# %%
(predictions>0.73).sum()
# Out:
# 965

# %%
confusion_matrix(clf.predict(pd.read_csv("final_train.csv")[features], \
                    num_iteration=clf.best_iteration)>0.7931777953657507, \
                    pd.read_csv("target_less31_bool.csv", index_col=0, header=None))
# Out:
# array([[198403,     23],
#        [  1307,   2184]])

# %%
cm1 = []
cm2 = []
cm3 = []
for t in np.linspace(0, 1, 100):
    cm = confusion_matrix(pre>t, target)
    cm1.append(cm[0][1])
    cm2.append(cm[1][0])
    cm3.append(cm[0][1]+cm[1][0])

# %%
cm = pd.DataFrame(index = np.linspace(0, 1, 100), columns=["cm1", "cm2", "cm3"])[["cm1", "cm2", "cm3"]]

# %%
cm["cm1"] = cm1
cm["cm2"] = cm2
cm["cm3"] = cm3

# %%
confusion_matrix(pre>0.955, target)
# Out:
# array([[199709,      0],
#        [     1, 200837]])

# %%
def origin_data_test(clf, th = 0.5):
    train = pd.read_csv('final_train.csv', index_col=0)
    target = (pd.read_csv("train.csv")['target']<-30).astype("int")
    return confusion_matrix(clf.predict(train[features], num_iteration=clf.best_iteration)>th, target)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-331-13bd796ca88f> in <module>
#       3     target = (pd.read_csv("train.csv")['target']<-30).astype("int")
#       4     return confusion_matrix(clf.predict(train[features], num_iteration=clf.best_iteration)>th, target)
# ----> 5 origin_data_test(clf)
#
# <ipython-input-331-13bd796ca88f> in origin_data_test(clf, th)
#       2     train = pd.read_csv('final_train.csv', index_col=0)
#       3     target = (pd.read_csv("train.csv")['target']<-30).astype("int")
# ----> 4     return confusion_matrix(clf.predict(train[features], num_iteration=clf.best_iteration)>th, target)
#       5 origin_data_test(clf)
#
# ~/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, pred_parameter, **kwargs)
#    2146         return predictor.predict(data, num_iteration,
#    2147                                  raw_score, pred_leaf, pred_contrib,
# -> 2148                                  data_has_header, is_reshape)
#    2149
#    2150     def refit(self, data, label, decay_rate=0.9, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py in predict(self, data, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     441             preds, nrow = self.__pred_for_csc(data, num_iteration, predict_type)
#     442         elif isinstance(data, np.ndarray):
# --> 443             preds, nrow = self.__pred_for_np2d(data, num_iteration, predict_type)
#     444         elif isinstance(data, list):
#     445             try:
#
# ~/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py in __pred_for_np2d(self, mat, num_iteration, predict_type)
#     532             return preds, nrow
#     533         else:
# --> 534             return inner_predict(mat, num_iteration, predict_type)
#     535
#     536     def __pred_for_csr(self, csr, num_iteration, predict_type):
#
# ~/anaconda3/lib/python3.6/site-packages/lightgbm/basic.py in inner_predict(mat, num_iteration, predict_type, preds)
#     514                 c_str(self.pred_parameter),
#     515                 ctypes.byref(out_num_preds),
# --> 516                 preds.ctypes.data_as(ctypes.POINTER(ctypes.c_double))))
#     517             if n_preds != out_num_preds.value:
#     518                 raise ValueError("Wrong length for predict results")
#
# KeyboardInterrupt:

# %%
origin_data_test(clf)

# %%
confusion_matrix(clf.predict(train[features], num_iteration=clf.best_iteration)>0.955, target)
# Out:
# array([[199709,      0],
#        [     1, 200837]])

# %%
confusion_matrix(clf.predict(pd.read_csv("final_train.csv")[features], num_iteration=clf.best_iteration)>0.955, target)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-408-41772dadf361> in <module>
# ----> 1 confusion_matrix(clf.predict(pd.read_csv("final_train.csv")[features], num_iteration=clf.best_iteration)>0.955, target)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     251
#     252     """
# --> 253     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     254     if y_type not in ("binary", "multiclass"):
#     255         raise ValueError("%s is not supported" % y_type)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# ~/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     228     if len(uniques) > 1:
#     229         raise ValueError("Found input variables with inconsistent numbers of"
# --> 230                          " samples: %r" % [int(l) for l in lengths])
#     231
#     232
#
# ValueError: Found input variables with inconsistent numbers of samples: [201917, 400547]

# %%
result = clf.predict(test[features])

# %%
np.save("test_cla_result2.ndarray", result)

# %%
cla_result = (result>0.5).astype("int")*(-33.219281) + (result<0.5).astype("int")*100

# %%
pd.value_counts(cla_result)
# Out:
#  100.000000    123417
# -33.219281        206
# dtype: int64

# %%
np.save("sum_cla2.ndarray", cla_result)

# %%
test = pd.read_csv("final_test.csv")

# %%
def submit_to_csv(result_array, submit_file):
    sub_df = pd.DataFrame(pd.read_csv("final_test.csv").card_id)
    sub_df["target"] = result_array
    sub_df.to_csv(submit_file, index=False)
    plt.figure(figsize=(20,12))
    sns.distplot(sub_df.target, bins=np.arange(-34, 16, 0.1), label='submission')
    sns.distplot(pd.read_csv("train.csv").target, bins=np.arange(-34, 16, 0.1), label='train')
    plt.legend()

# %%
lgb_drop_predictions = joblib.load('lgb_drop.pkl2').predict(pd.read_csv("final_test.csv")[features], \
                      num_iteration=joblib.load('lgb_drop.pkl2').best_iteration)
np.save("lgb_drop_predictions.npy",lgb_drop_predictions)

# %%
def submit_with_lgbm(result, submit_file):
    sub_df = pd.DataFrame()
    test_predictions = np.load("predictions_lgbm_without_31_1.npy")
    cla_result = (result>0.5).astype("int")*(-33.219281) + (result<0.5).astype("int")*100
    sub_df["cla_result"] = cla_result
    sub_df["predictions"] = test_predictions
    sub_df["submit"] = sub_df[["cla_result", "predictions"]].min(axis=1)
    submit_to_csv(sub_df["submit"], submit_file)

# %%
predictions = np.load("cla_logloss6.npy")

# %%
(predictions>0.129).sum()
# Out:
# 1000

# %%
predictions[np.argsort(predictions)[::-1][1000]]
# Out:
# 0.12897642707172216

# %%
sns.distplot(predictions)

# %%
predictions.shape
# Out:
# (123623,)

# %%
(predictions>0.92).sum()
# Out:
# 29

# %%
submit_with_lgbm( predictions>0.92,"submission13_92_.csv")

# %%
# submit_to_csv(np.load("predictions_lgbm_without_31_1.npy"), "submission8.csv")

# %%
pd.read_csv("test.csv").shape
# Out:
# (123623, 5)

# %%
submit_with_lgbm((predictions>0.7931777953657507), "submission7.csv")

# %%
(pd.read_csv("submission7.csv",index_col=0).target<-30).sum()
# Out:
# 1351

# %%
p = clf.predict(pd.read_csv("final_test.csv")[features], num_iteration=clf.best_iteration)

# %%
(pd.read_csv("train.csv").target<-30).sum()
# Out:
# 2207

# %%
pd.read_csv("test.csv").count()
# Out:
# first_active_month    123622
# card_id               123623
# feature_1             123623
# feature_2             123623
# feature_3             123623
# dtype: int64

# %%
2207/201917*123622
# Out:
# 1351.2173516841078

# %%
p.sort()

# %%
p[::-1][1351]
# Out:
# 0.22623448935476723

# %%
p[::-1][1350]
# Out:
# 0.22639385458769573

# %%
pt = clf.predict(pd.read_csv("final_test.csv")[features], num_iteration=clf.best_iteration)

# %%
(pt>0.2263).sum()
# Out:
# 1351

# %%
submit_with_lgbm(clf.predict(pd.read_csv("final_test.csv")[features], \
                             num_iteration=clf.best_iteration)>0.2263, "submission5_std_2263.csv")

# %%
pd.Series(lgb_drop_predictions)[pd.read_csv("train.csv").target>-30].std()
# Out:
# 0.7258377116400868

# %%
pd.Series(lgb_drop_predictions*2.366634993486182)[pd.read_csv("train.csv").target>-30].std()
# Out:
# 1.71779292795935

# %%
pd.read_csv("train.csv").target[pd.read_csv("train.csv").target>-30].std()
# Out:
# 1.7177929279593622

# %%
1.7177929279593622/0.7258377116400868
# Out:
# 2.366634993486182

# %%
lgb_drop_predictions
# Out:
# array([-0.51470933, -0.28376122, -0.61435344, ...,  1.07075238,
#        -0.8600213 ,  0.20450965])

# %%
sub_df = pd.DataFrame(test.card_id)

# %%
test_predictions = joblib.load('lgb_drop.pkl2').predict(test[features], num_iteration=joblib.load('lgb_drop.pkl2').best_iteration)

# %%
sub_df["cla_result"] = cla_result
sub_df["cla_result"]
# Out:
# 0         100.0
# 1         100.0
# 2         100.0
# 3         100.0
# 4         100.0
# 5         100.0
# 6         100.0
# 7         100.0
# 8         100.0
# 9         100.0
# 10        100.0
# 11        100.0
# 12        100.0
# 13        100.0
# 14        100.0
# 15        100.0
# 16        100.0
# 17        100.0
# 18        100.0
# 19        100.0
# 20        100.0
# 21        100.0
# 22        100.0
# 23        100.0
# 24        100.0
# 25        100.0
# 26        100.0
# 27        100.0
# 28        100.0
# 29        100.0
#           ...
# 123593    100.0
# 123594    100.0
# 123595    100.0
# 123596    100.0
# 123597    100.0
# 123598    100.0
# 123599    100.0
# 123600    100.0
# 123601    100.0
# 123602    100.0
# 123603    100.0
# 123604    100.0
# 123605    100.0
# 123606    100.0
# 123607    100.0
# 123608    100.0
# 123609    100.0
# 123610    100.0
# 123611    100.0
# 123612    100.0
# 123613    100.0
# 123614    100.0
# 123615    100.0
# 123616    100.0
# 123617    100.0
# 123618    100.0
# 123619    100.0
# 123620    100.0
# 123621    100.0
# 123622    100.0
# Name: cla_result, Length: 123623, dtype: float64

# %%
sub_df["predictions"] = test_predictions
sub_df["predictions"]
# Out:
# 0        -0.514709
# 1        -0.283761
# 2        -0.614353
# 3        -0.107774
# 4        -1.286803
# 5         0.684209
# 6         0.291856
# 7         0.991850
# 8        -0.727693
# 9        -0.363141
# 10       -0.630726
# 11        0.121853
# 12        0.158807
# 13       -0.001604
# 14       -0.269043
# 15        0.999744
# 16        0.416977
# 17       -0.022214
# 18        0.221099
# 19       -0.036588
# 20        0.136945
# 21       -0.690364
# 22        1.235656
# 23        0.251178
# 24       -0.129146
# 25        0.564134
# 26       -0.678302
# 27       -0.388615
# 28       -0.025524
# 29       -0.597130
#             ...
# 123593   -0.377060
# 123594   -1.463489
# 123595    0.076357
# 123596    1.255115
# 123597   -0.652566
# 123598   -0.441275
# 123599    0.618342
# 123600    0.034482
# 123601   -1.443397
# 123602   -0.185336
# 123603    0.038979
# 123604    0.799189
# 123605   -0.810803
# 123606   -0.234560
# 123607    0.673282
# 123608   -0.428860
# 123609   -0.065220
# 123610    0.408691
# 123611   -1.255123
# 123612   -0.592626
# 123613    0.150237
# 123614    1.204038
# 123615   -1.044701
# 123616    1.445057
# 123617    0.671721
# 123618    1.107118
# 123619   -0.412421
# 123620    1.070752
# 123621   -0.860021
# 123622    0.204510
# Name: predictions, Length: 123623, dtype: float64

# %%
sub_df["submit"] = sub_df[["cla_result", "predictions"]].min(axis=1)

# %%
submission = pd.DataFrame(sub_df["card_id"])
submission["target"] = sub_df["submit"]

# %%
submission[submission["target"]<-30].count()
# Out:
# card_id    206
# target     206
# dtype: int64

# %%
sns.distplot(submission.target)

# %%
# !head submission.csv
# Out:
# card_id,target
# C_ID_0ab67a22ab,-0.5147093309918691
# C_ID_130fd0cbdd,-0.28376121866065535
# C_ID_b709037bc5,-0.6143534355361029
# C_ID_d27d835a9f,-0.10777433896873057
# C_ID_2b5e3df5c2,-1.2868033050546757
# C_ID_5814b4f13c,0.684209053164266
# C_ID_a1b3c75277,0.2918555693941336
# C_ID_f7cada36d3,0.9918501626482662
# C_ID_9d2bc8dfc4,-0.7276931708877292

# %%
# !tail submission.csv
# Out:
# C_ID_b588b35e15,0.150237180317028
# C_ID_7147e348c3,1.2040384998396032
# C_ID_727d3ec5da,-1.044701030013962
# C_ID_107d93e20c,1.4450574232751638
# C_ID_0e74bd4966,0.6717210687044655
# C_ID_7a239d2eda,1.1071176637179527
# C_ID_75ace375ae,-0.41242071555137394
# C_ID_21d56d950c,1.0707523813575741
# C_ID_6c46fc5a9d,-0.8600213018175061
# C_ID_87e7979a5f,0.2045096470474171

# %%
# !head sample_submission.csv
# Out:
# card_id,target
# C_ID_0ab67a22ab,0
# C_ID_130fd0cbdd,0
# C_ID_b709037bc5,0
# C_ID_d27d835a9f,0
# C_ID_2b5e3df5c2,0
# C_ID_5814b4f13c,0
# C_ID_a1b3c75277,0
# C_ID_f7cada36d3,0
# C_ID_9d2bc8dfc4,0

# %%
# !tail sample_submission.csv
# Out:
# C_ID_b588b35e15,0
# C_ID_7147e348c3,0
# C_ID_727d3ec5da,0
# C_ID_107d93e20c,0
# C_ID_0e74bd4966,0
# C_ID_7a239d2eda,0
# C_ID_75ace375ae,0
# C_ID_21d56d950c,0
# C_ID_6c46fc5a9d,0
# C_ID_87e7979a5f,0

# %%
submission.to_csv("submission2.csv", index=False)

# %% [markdown]
# # Feature importance¶

# %%
cols = (feature_importance_df[["feature", "importance"]]
        .groupby("feature")
        .mean()
        .sort_values(by="importance", ascending=False)[:1000].index)

best_features = feature_importance_df.loc[feature_importance_df.feature.isin(cols)]

plt.figure(figsize=(14,25))
sns.barplot(x="importance",
            y="feature",
            data=best_features.sort_values(by="importance",
                                           ascending=False))
plt.title('LightGBM Features (avg over folds)')
plt.tight_layout()
plt.savefig('lgbm_importances.png')

# %%
sub_df = pd.DataFrame({"card_id":test["card_id"].values})
sub_df["target"] = predictions
sub_df.to_csv("submit.csv", index=False)

# %%
sub_df = pd.read_csv("submit.csv")

# %%
#train = pd.read_csv("train.csv", parse_dates=['first_active_month'])
plt.figure(figsize=(20,12))
sns.distplot(sub_df.target, bins=np.arange(-10, 10, 0.1), label='sub')
sns.distplot(train.target[train.target>-30], bins=np.arange(-10, 10, 0.1), label='train')
plt.legend()

# %%
plt.figure(figsize=(20,12))
sns.distplot(submission.target, bins=np.arange(-34, 16, 0.1), label='sub', color="b")
sns.distplot(pd.read_csv("train.csv").target, bins=np.arange(-34, 16, 0.1), label='train', color="r")
plt.legend()

# %%
sns.distplot(submission.target, bins=np.arange(-34, 16, 0.1), label='sub')

# %%
sns.distplot(pd.read_csv("train.csv").target, bins=np.arange(-34, 16, 0.1), label='train')

# %%
target.std()
# Out:
# 1.7177929279593622

# %%
submission["target"].std()
# Out:
# 1.7667418706984475

# %%
(submission["target"]<-30).sum() / submission["target"].shape[0]
# Out:
# 0.0023620200124572287

# %%
final_train = pd.read_csv("final_train.csv")

# %%
target = pd.read_csv("train.csv")["target"]

# %%
(original_train["target"]<-30).sum() / original_train["target"].shape[0]
# Out:
# 0.010930233709890698

# %%
lgb_drop = joblib.load("lgb_drop.pkl2")

# %%
train_less_31 = final_train[target<-30]

# %%
train_less_31_lgb_drop = lgb_drop.predict(train_less_31[features], num_iteration=lgb_drop.best_iteration)

# %%
sns.distplot(train_less_31_lgb_drop , bins=np.arange(-34, 16, 0.1), label='train')

# %%
from xgboost.sklearn import XGBClassifier

# %%
param = {'num_leaves': 111,
         'min_data_in_leaf': 149, 
         'objective':'binary',
         'max_depth': 9,
         'learning_rate': 0.005,
         "boosting": "gbdt",
         "feature_fraction": 0.7522,
         "bagging_freq": 1,
         "bagging_fraction": 0.7083 ,
         "bagging_seed": 11,
         "metric": 'rmse',
         "lambda_l1": 0.2634,
         "random_state": 133,
         "verbosity": -1}

# %%
xgbc = XGBClassifier(max_depth=9, learning_rate=0.01, n_estimators=500, 
                      silent=False, objective='binary:logistic', booster='gbtree', 
                      n_jobs=-1, nthread=8, gamma=0.1, 
                      reg_lambda=0.2634)

# %%
xgbc.fit(train_new[features], target_new, verbose=True )
# Out:
# [00:03:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 2 pruned nodes, max_depth=9
# [00:03:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 2 pruned nodes, max_depth=9
# [00:03:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 2 pruned nodes, max_depth=9
# [00:03:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 2 pruned nodes, max_depth=9
# [00:03:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 0 pruned nodes, max_depth=9
# [00:03:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 0 pruned nodes, max_depth=9
# [00:04:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 0 pruned nodes, max_depth=9
# [00:04:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 0 pruned nodes, max_depth=9
# [00:04:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 0 pruned nodes, max_depth=9
# [00:04:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 0 pruned nodes, max_depth=9
# [00:04:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 0 pruned nodes, max_depth=9
# [00:04:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 2 pruned nodes, max_depth=9
# [00:04:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 2 pruned nodes, max_depth=9
# [00:04:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 4 pruned nodes, max_depth=9
# [00:04:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 406 extra nodes, 0 pruned nodes, max_depth=9
# [00:04:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 0 pruned nodes, max_depth=9
# [00:04:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 4 pruned nodes, max_depth=9
# [00:04:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 2 pruned nodes, max_depth=9
# [00:04:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 2 pruned nodes, max_depth=9
# [00:04:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 2 pruned nodes, max_depth=9
# [00:04:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 2 pruned nodes, max_depth=9
# [00:04:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 0 pruned nodes, max_depth=9
# [00:04:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 2 pruned nodes, max_depth=9
# [00:04:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 430 extra nodes, 2 pruned nodes, max_depth=9
# [00:04:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 6 pruned nodes, max_depth=9
# [00:04:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 8 pruned nodes, max_depth=9
# [00:04:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 4 pruned nodes, max_depth=9
# [00:04:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 6 pruned nodes, max_depth=9
# [00:04:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 6 pruned nodes, max_depth=9
# [00:04:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 6 pruned nodes, max_depth=9
# [00:04:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 4 pruned nodes, max_depth=9
# [00:04:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 4 pruned nodes, max_depth=9
# [00:04:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 4 pruned nodes, max_depth=9
# [00:04:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 6 pruned nodes, max_depth=9
# [00:05:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 6 pruned nodes, max_depth=9
# [00:05:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 2 pruned nodes, max_depth=9
# [00:05:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 4 pruned nodes, max_depth=9
# [00:05:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 2 pruned nodes, max_depth=9
# [00:05:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 0 pruned nodes, max_depth=9
# [00:05:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 0 pruned nodes, max_depth=9
# [00:05:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 2 pruned nodes, max_depth=9
# [00:05:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 2 pruned nodes, max_depth=9
# [00:05:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 408 extra nodes, 2 pruned nodes, max_depth=9
# [00:05:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 6 pruned nodes, max_depth=9
# [00:05:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 8 pruned nodes, max_depth=9
# [00:05:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 4 pruned nodes, max_depth=9
# [00:05:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 8 pruned nodes, max_depth=9
# [00:05:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 8 pruned nodes, max_depth=9
# [00:05:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 4 pruned nodes, max_depth=9
# [00:05:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 0 pruned nodes, max_depth=9
# [00:05:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 4 pruned nodes, max_depth=9
# [00:05:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 8 pruned nodes, max_depth=9
# [00:05:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 0 pruned nodes, max_depth=9
# [00:05:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 414 extra nodes, 2 pruned nodes, max_depth=9
# [00:05:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 4 pruned nodes, max_depth=9
# [00:05:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 10 pruned nodes, max_depth=9
# [00:05:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 4 pruned nodes, max_depth=9
# [00:05:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 6 pruned nodes, max_depth=9
# [00:05:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 8 pruned nodes, max_depth=9
# [00:05:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 12 pruned nodes, max_depth=9
# [00:05:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 8 pruned nodes, max_depth=9
# [00:05:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 10 pruned nodes, max_depth=9
# [00:05:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 2 pruned nodes, max_depth=9
# [00:05:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 6 pruned nodes, max_depth=9
# [00:05:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 6 pruned nodes, max_depth=9
# [00:05:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 4 pruned nodes, max_depth=9
# [00:06:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 8 pruned nodes, max_depth=9
# [00:06:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 2 pruned nodes, max_depth=9
# [00:06:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 6 pruned nodes, max_depth=9
# [00:06:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 4 pruned nodes, max_depth=9
# [00:06:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 6 pruned nodes, max_depth=9
# [00:06:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 8 pruned nodes, max_depth=9
# [00:06:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 2 pruned nodes, max_depth=9
# [00:06:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 4 pruned nodes, max_depth=9
# [00:06:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 4 pruned nodes, max_depth=9
# [00:06:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 6 pruned nodes, max_depth=9
# [00:06:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 2 pruned nodes, max_depth=9
# [00:06:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 4 pruned nodes, max_depth=9
# [00:06:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 6 pruned nodes, max_depth=9
# [00:06:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 6 pruned nodes, max_depth=9
# [00:06:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 8 pruned nodes, max_depth=9
# [00:06:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 6 pruned nodes, max_depth=9
# [00:06:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 12 pruned nodes, max_depth=9
# [00:06:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 8 pruned nodes, max_depth=9
# [00:06:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 8 pruned nodes, max_depth=9
# [00:06:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 8 pruned nodes, max_depth=9
# [00:06:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 6 pruned nodes, max_depth=9
# [00:06:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 458 extra nodes, 6 pruned nodes, max_depth=9
# [00:06:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 8 pruned nodes, max_depth=9
# [00:06:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 16 pruned nodes, max_depth=9
# [00:06:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 10 pruned nodes, max_depth=9
# [00:06:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 10 pruned nodes, max_depth=9
# [00:06:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 472 extra nodes, 14 pruned nodes, max_depth=9
# [00:06:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 10 pruned nodes, max_depth=9
# [00:06:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 478 extra nodes, 14 pruned nodes, max_depth=9
# [00:06:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 14 pruned nodes, max_depth=9
# [00:06:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 18 pruned nodes, max_depth=9
# [00:06:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 466 extra nodes, 14 pruned nodes, max_depth=9
# [00:07:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 418 extra nodes, 16 pruned nodes, max_depth=9
# [00:07:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 12 pruned nodes, max_depth=9
# [00:07:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 446 extra nodes, 16 pruned nodes, max_depth=9
# [00:07:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 492 extra nodes, 8 pruned nodes, max_depth=9
# [00:07:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 16 pruned nodes, max_depth=9
# [00:07:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 480 extra nodes, 8 pruned nodes, max_depth=9
# [00:07:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 488 extra nodes, 16 pruned nodes, max_depth=9
# [00:07:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 4 pruned nodes, max_depth=9
# [00:07:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 10 pruned nodes, max_depth=9
# [00:07:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 502 extra nodes, 2 pruned nodes, max_depth=9
# [00:07:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 462 extra nodes, 6 pruned nodes, max_depth=9
# [00:07:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 498 extra nodes, 4 pruned nodes, max_depth=9
# [00:07:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 10 pruned nodes, max_depth=9
# [00:07:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 10 pruned nodes, max_depth=9
# [00:07:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 16 pruned nodes, max_depth=9
# [00:07:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 12 pruned nodes, max_depth=9
# [00:07:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 16 pruned nodes, max_depth=9
# [00:07:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 14 pruned nodes, max_depth=9
# [00:07:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 476 extra nodes, 10 pruned nodes, max_depth=9
# [00:07:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 428 extra nodes, 12 pruned nodes, max_depth=9
# [00:07:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 10 pruned nodes, max_depth=9
# [00:07:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 472 extra nodes, 10 pruned nodes, max_depth=9
# [00:07:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 440 extra nodes, 16 pruned nodes, max_depth=9
# [00:07:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 436 extra nodes, 12 pruned nodes, max_depth=9
# [00:07:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 10 pruned nodes, max_depth=9
# [00:07:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 14 pruned nodes, max_depth=9
# [00:07:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 12 pruned nodes, max_depth=9
# [00:07:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 444 extra nodes, 6 pruned nodes, max_depth=9
# [00:07:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 426 extra nodes, 2 pruned nodes, max_depth=9
# [00:07:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 8 pruned nodes, max_depth=9
# [00:07:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 2 pruned nodes, max_depth=9
# [00:07:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 454 extra nodes, 4 pruned nodes, max_depth=9
# [00:08:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 6 pruned nodes, max_depth=9
# [00:08:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 432 extra nodes, 4 pruned nodes, max_depth=9
# [00:08:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 8 pruned nodes, max_depth=9
# [00:08:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 0 pruned nodes, max_depth=9
# [00:08:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 10 pruned nodes, max_depth=9
# [00:08:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 470 extra nodes, 4 pruned nodes, max_depth=9
# [00:08:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 12 pruned nodes, max_depth=9
# [00:08:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 460 extra nodes, 6 pruned nodes, max_depth=9
# [00:08:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 448 extra nodes, 0 pruned nodes, max_depth=9
# [00:08:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 468 extra nodes, 10 pruned nodes, max_depth=9
# [00:08:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 8 pruned nodes, max_depth=9
# [00:08:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 10 pruned nodes, max_depth=9
# [00:08:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 474 extra nodes, 8 pruned nodes, max_depth=9
# [00:08:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 442 extra nodes, 8 pruned nodes, max_depth=9
# [00:08:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 464 extra nodes, 8 pruned nodes, max_depth=9
# [00:08:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 8 pruned nodes, max_depth=9
# [00:08:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 10 pruned nodes, max_depth=9
# [00:08:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 10 pruned nodes, max_depth=9
# [00:08:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 10 pruned nodes, max_depth=9
# [00:08:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 394 extra nodes, 12 pruned nodes, max_depth=9
# [00:08:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 14 pruned nodes, max_depth=9
# [00:08:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 12 pruned nodes, max_depth=9
# [00:08:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 8 pruned nodes, max_depth=9
# [00:08:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 8 pruned nodes, max_depth=9
# [00:08:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 4 pruned nodes, max_depth=9
# [00:08:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 6 pruned nodes, max_depth=9
# [00:08:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 6 pruned nodes, max_depth=9
# [00:08:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 4 pruned nodes, max_depth=9
# [00:08:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 4 pruned nodes, max_depth=9
# [00:08:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 4 pruned nodes, max_depth=9
# [00:08:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 2 pruned nodes, max_depth=9
# [00:08:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 2 pruned nodes, max_depth=9
# [00:09:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 2 pruned nodes, max_depth=9
# [00:09:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 2 pruned nodes, max_depth=9
# [00:09:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 2 pruned nodes, max_depth=9
# [00:09:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 6 pruned nodes, max_depth=9
# [00:09:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 2 pruned nodes, max_depth=9
# [00:09:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 2 pruned nodes, max_depth=9
# [00:09:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 396 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 400 extra nodes, 2 pruned nodes, max_depth=9
# [00:09:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 6 pruned nodes, max_depth=9
# [00:09:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 2 pruned nodes, max_depth=9
# [00:09:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 6 pruned nodes, max_depth=9
# [00:09:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 354 extra nodes, 8 pruned nodes, max_depth=9
# [00:09:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 6 pruned nodes, max_depth=9
# [00:09:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 6 pruned nodes, max_depth=9
# [00:09:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 6 pruned nodes, max_depth=9
# [00:09:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 6 pruned nodes, max_depth=9
# [00:09:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 4 pruned nodes, max_depth=9
# [00:09:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 4 pruned nodes, max_depth=9
# [00:10:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 6 pruned nodes, max_depth=9
# [00:10:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 6 pruned nodes, max_depth=9
# [00:10:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 4 pruned nodes, max_depth=9
# [00:10:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 6 pruned nodes, max_depth=9
# [00:10:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 2 pruned nodes, max_depth=9
# [00:10:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 402 extra nodes, 6 pruned nodes, max_depth=9
# [00:10:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 388 extra nodes, 6 pruned nodes, max_depth=9
# [00:10:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 404 extra nodes, 4 pruned nodes, max_depth=9
# [00:10:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 8 pruned nodes, max_depth=9
# [00:10:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 4 pruned nodes, max_depth=9
# [00:10:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 8 pruned nodes, max_depth=9
# [00:10:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 2 pruned nodes, max_depth=9
# [00:10:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 4 pruned nodes, max_depth=9
# [00:10:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 6 pruned nodes, max_depth=9
# [00:10:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 8 pruned nodes, max_depth=9
# [00:10:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 6 pruned nodes, max_depth=9
# [00:10:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 2 pruned nodes, max_depth=9
# [00:10:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 0 pruned nodes, max_depth=9
# [00:10:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 374 extra nodes, 8 pruned nodes, max_depth=9
# [00:10:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 10 pruned nodes, max_depth=9
# [00:10:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 12 pruned nodes, max_depth=9
# [00:10:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 10 pruned nodes, max_depth=9
# [00:10:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 8 pruned nodes, max_depth=9
# [00:10:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 10 pruned nodes, max_depth=9
# [00:10:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 4 pruned nodes, max_depth=9
# [00:10:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 8 pruned nodes, max_depth=9
# [00:10:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 10 pruned nodes, max_depth=9
# [00:10:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 16 pruned nodes, max_depth=9
# [00:10:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 6 pruned nodes, max_depth=9
# [00:10:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 6 pruned nodes, max_depth=9
# [00:10:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 10 pruned nodes, max_depth=9
# [00:10:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 380 extra nodes, 10 pruned nodes, max_depth=9
# [00:11:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 10 pruned nodes, max_depth=9
# [00:11:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 354 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 382 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 386 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 372 extra nodes, 8 pruned nodes, max_depth=9
# [00:11:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 2 pruned nodes, max_depth=9
# [00:11:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 368 extra nodes, 2 pruned nodes, max_depth=9
# [00:11:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 0 pruned nodes, max_depth=9
# [00:11:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 0 pruned nodes, max_depth=9
# [00:11:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 2 pruned nodes, max_depth=9
# [00:11:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 2 pruned nodes, max_depth=9
# [00:11:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 0 pruned nodes, max_depth=9
# [00:11:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 0 pruned nodes, max_depth=9
# [00:11:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 6 pruned nodes, max_depth=9
# [00:11:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 2 pruned nodes, max_depth=9
# [00:11:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 4 pruned nodes, max_depth=9
# [00:11:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 8 pruned nodes, max_depth=9
# [00:12:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 12 pruned nodes, max_depth=9
# [00:12:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 8 pruned nodes, max_depth=9
# [00:12:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 6 pruned nodes, max_depth=9
# [00:12:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 2 pruned nodes, max_depth=9
# [00:12:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 2 pruned nodes, max_depth=9
# [00:12:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 10 pruned nodes, max_depth=9
# [00:12:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 8 pruned nodes, max_depth=9
# [00:12:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 6 pruned nodes, max_depth=9
# [00:12:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 2 pruned nodes, max_depth=9
# [00:12:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 6 pruned nodes, max_depth=9
# [00:12:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 10 pruned nodes, max_depth=9
# [00:12:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 0 pruned nodes, max_depth=9
# [00:12:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 8 pruned nodes, max_depth=9
# [00:12:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 240 extra nodes, 10 pruned nodes, max_depth=9
# [00:12:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 0 pruned nodes, max_depth=9
# [00:12:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 236 extra nodes, 12 pruned nodes, max_depth=9
# [00:12:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 8 pruned nodes, max_depth=9
# [00:12:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 4 pruned nodes, max_depth=9
# [00:12:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 6 pruned nodes, max_depth=9
# [00:12:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 4 pruned nodes, max_depth=9
# [00:12:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 4 pruned nodes, max_depth=9
# [00:12:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 2 pruned nodes, max_depth=9
# [00:12:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 6 pruned nodes, max_depth=9
# [00:12:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 4 pruned nodes, max_depth=9
# [00:12:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 378 extra nodes, 4 pruned nodes, max_depth=9
# [00:12:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 384 extra nodes, 4 pruned nodes, max_depth=9
# [00:12:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 4 pruned nodes, max_depth=9
# [00:12:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 370 extra nodes, 8 pruned nodes, max_depth=9
# [00:12:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 376 extra nodes, 8 pruned nodes, max_depth=9
# [00:12:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 6 pruned nodes, max_depth=9
# [00:12:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 6 pruned nodes, max_depth=9
# [00:12:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 10 pruned nodes, max_depth=9
# [00:12:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 10 pruned nodes, max_depth=9
# [00:13:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 8 pruned nodes, max_depth=9
# [00:13:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 8 pruned nodes, max_depth=9
# [00:13:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 10 pruned nodes, max_depth=9
# [00:13:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 8 pruned nodes, max_depth=9
# [00:13:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 8 pruned nodes, max_depth=9
# [00:13:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 364 extra nodes, 10 pruned nodes, max_depth=9
# [00:13:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 10 pruned nodes, max_depth=9
# [00:13:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 12 pruned nodes, max_depth=9
# [00:13:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 340 extra nodes, 12 pruned nodes, max_depth=9
# [00:13:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 4 pruned nodes, max_depth=9
# [00:13:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 4 pruned nodes, max_depth=9
# [00:13:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 342 extra nodes, 4 pruned nodes, max_depth=9
# [00:13:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 354 extra nodes, 6 pruned nodes, max_depth=9
# [00:13:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 6 pruned nodes, max_depth=9
# [00:13:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 2 pruned nodes, max_depth=9
# [00:13:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 4 pruned nodes, max_depth=9
# [00:13:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 6 pruned nodes, max_depth=9
# [00:13:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 4 pruned nodes, max_depth=9
# [00:13:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 10 pruned nodes, max_depth=9
# [00:13:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 14 pruned nodes, max_depth=9
# [00:13:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 8 pruned nodes, max_depth=9
# [00:13:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 6 pruned nodes, max_depth=9
# [00:13:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 4 pruned nodes, max_depth=9
# [00:13:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 4 pruned nodes, max_depth=9
# [00:13:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 8 pruned nodes, max_depth=9
# [00:13:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 10 pruned nodes, max_depth=9
# [00:13:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 312 extra nodes, 10 pruned nodes, max_depth=9
# [00:13:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 8 pruned nodes, max_depth=9
# [00:13:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 350 extra nodes, 2 pruned nodes, max_depth=9
# [00:13:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 6 pruned nodes, max_depth=9
# [00:13:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 8 pruned nodes, max_depth=9
# [00:13:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 12 pruned nodes, max_depth=9
# [00:14:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 12 pruned nodes, max_depth=9
# [00:14:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 336 extra nodes, 12 pruned nodes, max_depth=9
# [00:14:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 8 pruned nodes, max_depth=9
# [00:14:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 398 extra nodes, 4 pruned nodes, max_depth=9
# [00:14:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 320 extra nodes, 16 pruned nodes, max_depth=9
# [00:14:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 10 pruned nodes, max_depth=9
# [00:14:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 4 pruned nodes, max_depth=9
# [00:14:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 420 extra nodes, 6 pruned nodes, max_depth=9
# [00:14:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 348 extra nodes, 8 pruned nodes, max_depth=9
# [00:14:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 346 extra nodes, 10 pruned nodes, max_depth=9
# [00:14:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 412 extra nodes, 12 pruned nodes, max_depth=9
# [00:14:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 8 pruned nodes, max_depth=9
# [00:14:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 16 pruned nodes, max_depth=9
# [00:14:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 12 pruned nodes, max_depth=9
# [00:14:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 10 pruned nodes, max_depth=9
# [00:14:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 6 pruned nodes, max_depth=9
# [00:14:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 332 extra nodes, 4 pruned nodes, max_depth=9
# [00:14:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 16 pruned nodes, max_depth=9
# [00:14:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 318 extra nodes, 6 pruned nodes, max_depth=9
# [00:14:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 352 extra nodes, 10 pruned nodes, max_depth=9
# [00:14:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 2 pruned nodes, max_depth=9
# [00:14:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 12 pruned nodes, max_depth=9
# [00:14:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 248 extra nodes, 6 pruned nodes, max_depth=9
# [00:14:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 356 extra nodes, 10 pruned nodes, max_depth=9
# [00:14:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 6 pruned nodes, max_depth=9
# [00:14:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 314 extra nodes, 2 pruned nodes, max_depth=9
# [00:14:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 12 pruned nodes, max_depth=9
# [00:14:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 298 extra nodes, 4 pruned nodes, max_depth=9
# [00:14:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 12 pruned nodes, max_depth=9
# [00:14:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 344 extra nodes, 2 pruned nodes, max_depth=9
# [00:14:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 238 extra nodes, 8 pruned nodes, max_depth=9
# [00:14:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 0 pruned nodes, max_depth=9
# [00:14:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 2 pruned nodes, max_depth=9
# [00:15:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 450 extra nodes, 4 pruned nodes, max_depth=9
# [00:15:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 8 pruned nodes, max_depth=9
# [00:15:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 452 extra nodes, 4 pruned nodes, max_depth=9
# [00:15:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 434 extra nodes, 6 pruned nodes, max_depth=9
# [00:15:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 268 extra nodes, 8 pruned nodes, max_depth=9
# [00:15:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 2 pruned nodes, max_depth=9
# [00:15:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 4 pruned nodes, max_depth=9
# [00:15:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 286 extra nodes, 8 pruned nodes, max_depth=9
# [00:15:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 330 extra nodes, 8 pruned nodes, max_depth=9
# [00:15:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 6 pruned nodes, max_depth=9
# [00:15:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 10 pruned nodes, max_depth=9
# [00:15:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 278 extra nodes, 10 pruned nodes, max_depth=9
# [00:15:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 264 extra nodes, 4 pruned nodes, max_depth=9
# [00:15:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 280 extra nodes, 6 pruned nodes, max_depth=9
# [00:15:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 422 extra nodes, 8 pruned nodes, max_depth=9
# [00:15:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 14 pruned nodes, max_depth=9
# [00:15:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 4 pruned nodes, max_depth=9
# [00:15:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 14 pruned nodes, max_depth=9
# [00:15:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 296 extra nodes, 4 pruned nodes, max_depth=9
# [00:15:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 324 extra nodes, 0 pruned nodes, max_depth=9
# [00:15:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 366 extra nodes, 10 pruned nodes, max_depth=9
# [00:15:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 8 pruned nodes, max_depth=9
# [00:15:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 276 extra nodes, 8 pruned nodes, max_depth=9
# [00:15:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 2 pruned nodes, max_depth=9
# [00:15:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 424 extra nodes, 6 pruned nodes, max_depth=9
# [00:15:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 4 pruned nodes, max_depth=9
# [00:15:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 6 pruned nodes, max_depth=9
# [00:15:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 2 pruned nodes, max_depth=9
# [00:15:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 304 extra nodes, 8 pruned nodes, max_depth=9
# [00:15:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 12 pruned nodes, max_depth=9
# [00:15:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 4 pruned nodes, max_depth=9
# [00:15:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 358 extra nodes, 4 pruned nodes, max_depth=9
# [00:15:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 6 pruned nodes, max_depth=9
# [00:16:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 362 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 338 extra nodes, 8 pruned nodes, max_depth=9
# [00:16:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 310 extra nodes, 8 pruned nodes, max_depth=9
# [00:16:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 10 pruned nodes, max_depth=9
# [00:16:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 326 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 316 extra nodes, 8 pruned nodes, max_depth=9
# [00:16:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 322 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 300 extra nodes, 6 pruned nodes, max_depth=9
# [00:16:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 234 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 360 extra nodes, 6 pruned nodes, max_depth=9
# [00:16:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 274 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 2 pruned nodes, max_depth=9
# [00:16:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 2 pruned nodes, max_depth=9
# [00:16:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 302 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 2 pruned nodes, max_depth=9
# [00:16:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 2 pruned nodes, max_depth=9
# [00:16:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 328 extra nodes, 6 pruned nodes, max_depth=9
# [00:16:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 308 extra nodes, 6 pruned nodes, max_depth=9
# [00:16:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 292 extra nodes, 8 pruned nodes, max_depth=9
# [00:16:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 390 extra nodes, 10 pruned nodes, max_depth=9
# [00:16:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 272 extra nodes, 2 pruned nodes, max_depth=9
# [00:16:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 392 extra nodes, 6 pruned nodes, max_depth=9
# [00:16:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 262 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 2 pruned nodes, max_depth=9
# [00:16:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 416 extra nodes, 6 pruned nodes, max_depth=9
# [00:16:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 252 extra nodes, 2 pruned nodes, max_depth=9
# [00:16:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 4 pruned nodes, max_depth=9
# [00:16:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 226 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 410 extra nodes, 8 pruned nodes, max_depth=9
# [00:17:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 334 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 2 pruned nodes, max_depth=9
# [00:17:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 12 pruned nodes, max_depth=9
# [00:17:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 290 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 246 extra nodes, 10 pruned nodes, max_depth=9
# [00:17:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 270 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 12 pruned nodes, max_depth=9
# [00:17:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 10 pruned nodes, max_depth=9
# [00:17:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 256 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 244 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 284 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 206 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 282 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 216 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 198 extra nodes, 12 pruned nodes, max_depth=9
# [00:17:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 180 extra nodes, 12 pruned nodes, max_depth=9
# [00:17:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 196 extra nodes, 4 pruned nodes, max_depth=9
# [00:17:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 294 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 12 pruned nodes, max_depth=9
# [00:17:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 6 pruned nodes, max_depth=9
# [00:17:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 260 extra nodes, 6 pruned nodes, max_depth=9
# [00:18:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 166 extra nodes, 4 pruned nodes, max_depth=9
# [00:18:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 254 extra nodes, 8 pruned nodes, max_depth=9
# [00:18:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 202 extra nodes, 8 pruned nodes, max_depth=9
# [00:18:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 164 extra nodes, 4 pruned nodes, max_depth=9
# [00:18:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 4 pruned nodes, max_depth=9
# [00:18:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 214 extra nodes, 0 pruned nodes, max_depth=9
# [00:18:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 194 extra nodes, 12 pruned nodes, max_depth=9
# [00:18:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 208 extra nodes, 2 pruned nodes, max_depth=9
# [00:18:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 258 extra nodes, 6 pruned nodes, max_depth=9
# [00:18:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 178 extra nodes, 8 pruned nodes, max_depth=9
# [00:18:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 162 extra nodes, 8 pruned nodes, max_depth=9
# [00:18:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 192 extra nodes, 8 pruned nodes, max_depth=9
# [00:18:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 220 extra nodes, 2 pruned nodes, max_depth=9
# [00:18:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 288 extra nodes, 2 pruned nodes, max_depth=9
# [00:18:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 6 pruned nodes, max_depth=9
# [00:18:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 168 extra nodes, 6 pruned nodes, max_depth=9
# [00:18:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 0 pruned nodes, max_depth=9
# [00:18:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 174 extra nodes, 6 pruned nodes, max_depth=9
# [00:18:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 0 pruned nodes, max_depth=9
# [00:18:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 266 extra nodes, 4 pruned nodes, max_depth=9
# [00:18:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 212 extra nodes, 4 pruned nodes, max_depth=9
# [00:18:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 250 extra nodes, 10 pruned nodes, max_depth=9
# [00:18:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 172 extra nodes, 4 pruned nodes, max_depth=9
# [00:18:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 224 extra nodes, 4 pruned nodes, max_depth=9
# [00:18:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 204 extra nodes, 2 pruned nodes, max_depth=9
# [00:18:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 176 extra nodes, 6 pruned nodes, max_depth=9
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0.1, learning_rate=0.01, max_delta_step=0,
#        max_depth=9, min_child_weight=1, missing=None, n_estimators=500,
#        n_jobs=-1, nthread=8, objective='binary:logistic', random_state=0,
#        reg_alpha=0, reg_lambda=0.2634, scale_pos_weight=1, seed=None,
#        silent=False, subsample=1)

# %%
confusion_matrix(xgbc.predict(final_train[features]), target<-30)
# Out:
# array([[183148,      0],
#        [ 16562,   2207]])

# %% [markdown]
# # xlearn
